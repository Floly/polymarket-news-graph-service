# %%
import sys

sys.path.insert(0, '../')

# %%
from urllib.parse import urlparse

from utils.parsers import PolymarketAPIClient, PriceHistoryFetcher
from utils.base import DateConverter
from utils.parsers import fetch_google_news_rss, get_real_url_async

from pathlib import Path

import os
import random
import asyncio
import itertools
import json
import logging
from datetime import datetime, timedelta

url = 'https://polymarket.com/event/largest-company-end-of-may'
o = urlparse(url)

slug = o.path.split('/')[2]

event_api = PolymarketAPIClient("https://gamma-api.polymarket.com/events")
price_api = PriceHistoryFetcher(PolymarketAPIClient("https://clob.polymarket.com/prices-history/"))

res = event_api.get_events(params={'slug': slug})

# %%
ROOT =  f"../data/inference_data/"
event = res[0]
event_id = event['id']
event_path = f'{ROOT}{event_id}'
Path(f'{event_path}/sentence_embeddings/').mkdir(parents=True, exist_ok=True)


# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    filename=f'../logs/{event_id}.log'
)

handler = logging.StreamHandler()
handler.setLevel(logging.WARNING)
logging.getLogger().addHandler(handler)
logger = logging.getLogger(__name__)

# Сбор отдельного ивента
now = datetime.now()
end_ts = now.timestamp()
start_ts = max(
    (now - timedelta(days=14)).timestamp(), 
    DateConverter().iso_or_yy_mm_dd_to_unix(res[0]['markets'][0]['startDate'])
)

for m in event['markets']:
    
    prices = []
    try:
        tid = m['clobTokenIds']
    except KeyError:
        continue
    for market_id in eval(tid):

        price = price_api.fetch_prices_history(
            market_id=market_id,
            start_ts=start_ts,
            end_ts=end_ts,
            fidelity=60
        )

        prices.append(price)
        
    m['prices_history'] = prices


with open(f'{event_path}/event.json', 'w') as f:
    json.dump(event, f)
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# SSLError: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/miniconda/envs/diploma_env/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/util/retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='clob.polymarket.com', port=443): Max retries exceeded with url: /prices-history/?market=26840969418190051427599175382220987005102672149573610325117060079934763731527&startTs=1746304013.249933&endTs=1747513613.249933&fidelity=60 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# Cell In[123], line 37
#      34     continue
#      35 for market_id in eval(tid):
# ---> 37     price = price_api.fetch_prices_history(
#      38         market_id=market_id,
#      39         start_ts=start_ts,
#      40         end_ts=end_ts,
#      41         fidelity=60
#      42     )
#      44     prices.append(price)
#      46 m['prices_history'] = prices
#
# File ~/Desktop/Учеба/МОВС_ВШЭ/Диплом/pm_news_graph/notebooks/../utils/parsers.py:60, in PriceHistoryFetcher.fetch_prices_history(self, market_id, start_ts, end_ts, fidelity)
#      53 url = "https://clob.polymarket.com/prices-history/"
#      54 params = {
#      55     "market": market_id,
#      56     "startTs": start_ts,
#      57     "endTs": end_ts,
#      58     "fidelity": fidelity
#      59 }
# ---> 60 response = requests.get(url, params=params)
#      61 response.raise_for_status()
#      63 return response.json()
#
# File ~/miniconda/envs/diploma_env/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniconda/envs/diploma_env/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda/envs/diploma_env/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda/envs/diploma_env/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda/envs/diploma_env/lib/python3.11/site-packages/requests/adapters.py:698, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     694         raise ProxyError(e, request=request)
#     696     if isinstance(e.reason, _SSLError):
#     697         # This branch is for urllib3 v1.22 and later.
# --> 698         raise SSLError(e, request=request)
#     700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#
# SSLError: HTTPSConnectionPool(host='clob.polymarket.com', port=443): Max retries exceeded with url: /prices-history/?market=26840969418190051427599175382220987005102672149573610325117060079934763731527&startTs=1746304013.249933&endTs=1747513613.249933&fidelity=60 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)')))

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline
from tqdm import tqdm
import json
import spacy
import logging


with open(f"{event_path}/event.json", "r") as f:
    event = json.load(f)

# Configuration
entities_path = f"{event_path}/entities.json"


# Load NLP models
try:
    spacy_nlp = spacy.load("en_core_web_sm")
except Exception as e:
    logger.error(f"Failed to load spaCy model: {e}")
    exit(1)

try:
    tokenizer = AutoTokenizer.from_pretrained(
        "dslim/bert-base-NER", tokenizer_args={"do_basic_tokenize": False}
    )
    bert_model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")
    bert_ner_pipeline = pipeline("ner", model=bert_model, tokenizer=tokenizer, aggregation_strategy="first")
except Exception as e:
    logger.error(f"Failed to load BERT NER model: {e}")
    exit(1)

# Dictionary to hold final results
event_entities = {}

# Load SpaCy for stopword detection
nlp = spacy.load("en_core_web_sm")

# Process each event
try:
    if not event:
        logger.warning("Missing 'event' key in event.")

    event_id = event.get("id")
    event_title = event.get("title")
    event_description = event.get("description")

    # Validate description
    if not isinstance(event_description, str):
        logger.warning(f"Invalid description for event ID {event_id}: {type(event_description)}")
        event_description = ""

    # Extract entities using BERT NER
    try:
        bert_entities = list({
            ent["word"].lower() 
            for ent in bert_ner_pipeline(event_description)
            if not nlp(ent["word"].lower())[0].is_stop
            }) if event_description else []
    except Exception as e:
        logger.error(f"BERT NER error for event {event_id}: {e}")
        bert_entities = []

    # Extract tags
    tags = event.get("tags", [])
    tag_labels = list({tag.get("label", "").lower() for tag in tags if tag.get("label")})
    tag_slugs = list({tag.get("slug", "") for tag in tags if tag.get("slug")})

    # Prepare event entity dictionary
    event_entities_dict = {
        "event_title": event_title,
        "event_ents_bert": bert_entities,
        "tag_labels": tag_labels,
        "tag_slugs": tag_slugs,
        "market_ents": {},
    }

    # Process market questions
    m_ents = {}
    markets = event.get("markets", [])
    for market in markets:

        market_id = market.get("id")
        market_question = market.get("question")

        if not isinstance(market_question, str):
            logger.warning(f"Invalid market question for market ID {market_id}")
            market_question = ""


        m_ents[market_id] = market_question

    event_entities_dict["market_ents"] = m_ents
    event_entities[event_id] = event_entities_dict

except Exception as e:
    logger.error(f"Unexpected error processing event data: {e}")

# Save results to file
try:
    json.dump(event_entities, open(entities_path, "w"), indent=2)
    logger.info(f"Results saved to {entities_path}")
except Exception as e:
    logger.error(f"Failed to save results: {e}")
# Out:
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use mps:0

# %%
ARTICLES_PATH = f'{event_path}/articles.json'
entities_path = f'{event_path}/entities.json'

MAX_SAMPLE_SIZE = 100

def get_extracted_events(path=ARTICLES_PATH):
    urls = os.listdir(path)
    result = [u.split('_')[0] for u in urls]
    return result
    
def fetch_news_for_queries(queries, cutoff_date):
    """Fetch news 
    for a list of queries and a cutoff date."""
    logger.info(f"Fetching news for {len(queries)} queries (cutoff: {cutoff_date})")
    news_data = {}
    for query in queries:
        try:
            res = fetch_google_news_rss(query, cutoff_date=cutoff_date)
            if res:
                news_data.update(res)
        except Exception as e:
            logger.error(f"Error fetching news for query '{query}': {e}")
    return news_data

async def url_extractor(event_id, articles, num_parallel_tasks=10):
    """
    Extract real URLs from articles in parallel using a specified number of tasks.
    
    Args:
        event_id (str): ID of the event.
        articles (list): List of article dicts.
        num_parallel_tasks (int): Number of parallel coroutines to use.
    """
    logger.info(f"Processing {len(articles)} articles for event ID: {event_id}")
    
    # Sample 100 articles if total exceeds 100
    if len(articles) > MAX_SAMPLE_SIZE:
        logger.warning(f"Exceeded {MAX_SAMPLE_SIZE} articles. Sampling {MAX_SAMPLE_SIZE} out of {len(articles)}.")
        articles = random.sample(articles, MAX_SAMPLE_SIZE)
        logger.info(f"Sampled {MAX_SAMPLE_SIZE} articles for event ID: {event_id}")

    # Create chunks based on number of parallel tasks
    chunk_size = max(1, len(articles) // num_parallel_tasks)
    chunks = [
        articles[i:i + chunk_size]
        for i in range(0, len(articles), chunk_size)
    ]

    logger.info(f"Created {len(chunks)} chunks for parallel processing")

    # Run all chunks in parallel using get_real_url_async
    tasks = [get_real_url_async(chunk) for chunk in chunks]
    results = await asyncio.gather(*tasks)
    combined_articles = []
    for result in results:
        combined_articles.extend(result)

    output_path = ARTICLES_PATH
    try:
        with open(output_path, 'w') as f:
            json.dump(combined_articles, f)
        logger.info(f"Saved processed articles to {output_path}")
    except Exception as e:
        logger.error(f"Failed to save articles for event ID {event_id}: {e}")

async def news_parsing(event):
    """Main function to process events and fetch related news articles."""
    event_id = event['id']
    
    with open(entities_path, 'r') as f:
        event_ents = json.load(f)
    

    logger.warning(f"Starting processing for event ID: {event_id}")
    markets = event['markets']

    last_date_str = datetime.now().strftime('%Y-%m-%d')

    tags = event_ents[event_id]['tag_labels']
    tag_combinations = list(itertools.combinations(tags, len(tags)))
    tag_queries = [' '.join(combo) for combo in tag_combinations]

    # Collect all queries from different sources
    queries = []
    queries.extend(event_ents[event_id]['event_ents_bert'])
    queries.extend(tag_queries)
    queries.extend([m.get('question') for m in markets])

    news_data = fetch_news_for_queries(queries, last_date_str)

    articles = [
        {**article, 'query': source}
        for source, articles_list in news_data.items()
        for article in articles_list
    ]

    await url_extractor(event_id, articles, num_parallel_tasks=20)

import nest_asyncio
nest_asyncio.apply()

await news_parsing(event)
# Out:
# Starting processing for event ID: 23935
# Starting processing for event ID: 23935
# Exceeded 100 articles. Sampling 100 out of 623.
# Exceeded 100 articles. Sampling 100 out of 623.
# 🧭 Navigating to https://news.google.com/rss/articles/CBMipgFBVV95cUxOZzI1dEl4ZUN6TlNrVjRWREtGLTRJRmx4ZWZKbjA1UmExRVpFWTg0bW45YWJOeEFEb1h1dk9yTkE4T05vczV5WXhaNThrS1JDWnJKa0ZvQUwtajA0YTFOZmdwTXB2S3FpcnE2Y0ZwTHNmSk5CcnJOa2xkdnJQM1hDVldCMFdwMTczR1h6Y3NUanR3S0hmWDNza25UWWlQeFkzS01qa19B?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMikwFBVV95cUxOc0Nqbi1NSGwxZ2E0QU1WZHdETlRPVXF5aWJpQ1JYY25RMS1GejNGdUVVSURYTTVTX3gyeGZ6WXc2ZGZtaTYweTAyTFhHSGQxQjhJYTJKSjVOQnpJanE1cTZHUVh0eUFqQWdRLUdlZ2tEaHRCMnhxMDI1d0tBdjhTRzF1VlhMUy1Kb1ZGRXdTa0VfQ1E?oc=5
# 🧭 Navigating to https://news.google.?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMiekFVX3lxTFBOTVZpY0RqbEtrX09DZzY4d3lnN2dKQmF4RV80WTUyX1NrQjZpcm5aMTZMQXhlRVhJWkRHWUtHdGFFWGFSc2piY0hvVkd1ZU96VExHVGh1dFZlcVpsb3hYSmpGMFN4QXhmakxiSDViOTZfMklPdTRpeURR?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMikgFBVV95cUxOMU9CblMxcTlUZnlzMWY4MUV1X1NDbE16dHdUc214WUt3TDdsVWVXU0k0dGlRaWxqQ28wWlFQbE1WSFBQNnZiZWUzVU1XM3gyUGNjUG1SaEVHOXdTMW1tVy1tdVRBa3VKcWItUENGLVJiV0syNm9iY3JyQ2RybUhRRURKS0RWYllzV1dhRkU0OGlNZw?oc=5
# 🧭 Navigating to https://news.google.?oc=5
# 🧭 Navigating to https://news.google....?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMingFBVV95cUxQcHViUnRReHRZNVFTY203TWZ0N2hYdkQyUDZ1aTNIdzFRQ21QdTM2aE9FNUgyTllRZjNUd0t6T2tJT25qREZtUWJSUERJWFdoRWdFdUlMUGgtZUs2TTh3TWMtSndGcklIR0ZqYzhSZjZGSi1UWGtycVhJek5NUENhc3R2UVJGa21aRy10VGsydlB2STNDbExCSVhXWTJrUQ?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMikwFBVV95cUxOc0Nqbi1NSGwxZ2E0QU1WZHdETlRPVXF5aWJpQ1JYY25RMS1GejNGdUVVSURYTTVTX3gyeGZ6WXc2ZGZtaTYweTAyTFhHSGQxQjhJYTJKSjVOQnpJanE1cTZHUVh0eUFqQWdRLUdlZ2tEaHRCMnhxMDI1d0tBdjhTRzF1VlhMUy1Kb1ZGRXdTa0VfQ1E?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMinAFBVV95cUxNR0VhcTA4a2xtYy1kVzdHSGZFSUdpQmZGYmVMXzJHMVJFX3Z0Njc4V2JaUEVvOWhxVmxrY3ZlMFlsSVVXNjhhMnNsU2RiZFd1OEtSajFSZ1JwbjZjbDFzcmtnRUw0RnphMUVFWHNjdi1GMm51WERQTGlPeWFRaDhSWTV2NzdCN3lRbTNUQWNDOEJ4cDdiQ3V5UXFDZnA?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMingFBVV95cUxPNkcweE4yQldQakg5ZGtYNTI0bTREaUx3ekNjWDE1eUFGWUlWTzlZMm15YkZXYVhGeEd0bDF5VDZKdkxjYkpzeEJMQV9KM2VuZGhnaDhHcXR1NWYwV0VVZ3ZqaFlFcHk4XzE5RG5VeFZPUWg5VWJPM25RYWxvZ0huMzJWcW9TSWFvU3RvSkFZcFMyZUNGNG5vX0dzdWt6dw?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMikgFBVV95cUxNdXJodUxtWmExMDFCdUx3OGdOR1ExRXdoeXFrMGpuZ1VtblpkU1Y1MWI0YW5ibWdFMmVnRWZRem1mUE00NzZZeHdJVENBSUJtQXFlcGJxMGdkUmtUZm42RE9LdEhmbjR1cldjalFEX0dhaU5VWklHREc4dW9qM2g2NjVVdlBLVEI3NDM5a293SXQwdw?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMijAFBVV95cUxNWTlMTUg3Tk9pSUhlQ2lsVWNzYlgwSFRuU0lQVklpVEZ3aldyWV9tLVhMRG93cThaOWlUbXhLSi1lTjNTYlhZcGlUZUlUcjlRQWh5RmJjUUxYbm1yZlJ2SkYwOGVwOEVObE9zWV81MXp5NkllRnlGc1NnU2E5c2daRzFzMHdnaEE1Q0VGdA?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMi-?oc=5
# 🧭 Navigating to https://news.google.?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMihwFBVV95cUxQaXlvUzlTaUYzRERXT1AzeGs4MEI2V2dYenRVWmZFek13Z2d2ek02ZEVIdXRlOS1VdEh1MUpwbUR2ODJPbkFBc1NLY3pveFpfZm0wejN4Y3haeGVtQ2JocmphZ3F4bXNWX0RqRnptU2xlYmFoNmxnNERiZk1NYlM4anh5OGhRNjQ?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMimgFBVV95cUxNLXhtcTloUTRmTjlDWnQzbG5qaGFVOC1vSG9sREtSN2pEb0xQeGdDVnpIXzZUV21PVlZIS3NXcEZSM243aHJJZzAzOXRZWktaWVUtLXR3LTJ0WUc2VUVPNU43RXpQLWZfUWFsa19WdnRtVjBkUjExSVh1QmJNTDR3bk5FUm9NcTZwZ0dOaWZVcTdIZkRlcmNQZjF3?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMikgFBVV95cUxNdXJodUxtWmExMDFCdUx3OGdOR1ExRXdoeXFrMGpuZ1VtblpkU1Y1MWI0YW5ibWdFMmVnRWZRem1mUE00NzZZeHdJVENBSUJtQXFlcGJxMGdkUmtUZm42RE9LdEhmbjR1cldjalFEX0dhaU5VWklHREc4dW9qM2g2NjVVdlBLVEI3NDM5a293SXQwdw?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMijAFBVV95cUxNWTlMTUg3Tk9pSUhlQ2lsVWNzYlgwSFRuU0lQVklpVEZ3aldyWV9tLVhMRG93cThaOWlUbXhLSi1lTjNTYlhZcGlUZUlUcjlRQWh5RmJjUUxYbm1yZlJ2SkYwOGVwOEVObE9zWV81MXp5NkllRnlGc1NnU2E5c2daRzFzMHdnaEE1Q0VGdA?oc=5
# 🧭 Navigating to https://news.google.?oc=5
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 35 elements. Proceeding with the first one: <a data-hook="link" href="https://www.aussievision.net" class="blog-navigation-container-color blog-navigation-container-font  blog-navigation-link-hover-color">All Posts</a>
#   - attempting click action
#     2 × waiting for element to be visible, enabled and stable
#       - element is not visible
#     - retrying click action
#     - waiting 20ms
#     2 × waiting for element to be visible, enabled and stable
#       - element is not visible
#     - retrying click action
#       - waiting 100ms
#     6 × waiting for element to be visible, enabled and stable
#       - element is not visible
#     - retrying click action
#       - waiting 500ms
#
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 570 elements. Proceeding with the first one: <a rel="category tag" href="https://wiwibloggs.com/category/news/eurovision-song-contest-2025/">Eurovision Song Contest 2025</a>
#   - attempting click action
#     - waiting for element to be visible, enabled and stable
#     - element is visible, enabled and stable
#     - scrolling into view if needed
#     - done scrolling
#     - performing click action
#
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 57 elements. Proceeding with the first one: <a data-vars-ga-position="2" data-theme-key="base-link" data-vars-cta="SpotlightNav-Pill" data-vars-ga-outbound-link="false" class="e65xy7j7 css-209q5s e1c1bym14" data-vars-ga-ux-element="Spotlight Nav" href="/entertainment/music/a43875781/eurovision-2023-how-to-watch/">Your Guide To Eurovision 2023</a>
#   - attempting click action
#     2 × waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <journey-modal-newsletter data-ad-exclude="" data-is-signed-in="false" data-target-selector="#journey-modal-container" data-template-id="4ebed81d-7db4-48db-89dc-c866fba20e3f"></journey-modal-newsletter> intercepts pointer events
#     - retrying click action
#     - waiting 20ms
#     2 × waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <journey-modal-newsletter data-ad-exclude="" data-is-signed-in="false" data-target-selector="#journey-modal-container" data-template-id="4ebed81d-7db4-48db-89dc-c866fba20e3f"></journey-modal-newsletter> intercepts pointer events
#     - retrying click action
#       - waiting 100ms
#     2 × waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <journey-modal-newsletter data-ad-exclude="" data-is-signed-in="false" data-target-selector="#journey-modal-container" data-template-id="4ebed81d-7db4-48db-89dc-c866fba20e3f"></journey-modal-newsletter> intercepts pointer events
#     - retrying click action
#       - waiting 500ms
#
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 35 elements. Proceeding with the first one: <a data-hook="link" href="https://www.aussievision.net" class="blog-navigation-container-color blog-navigation-container-font  blog-navigation-link-hover-color">All Posts</a>
#   - attempting click action
#     2 × waiting for element to be visible, enabled and stable
#       - element is not visible
#     - retrying click action
#     - waiting 20ms
#     2 × waiting for element to be visible, enabled and stable
#       - element is not visible
#     - retrying click action
#       - waiting 100ms
#     4 × waiting for element to be visible, enabled and stable
#       - element is not visible
#     - retrying click action
#       - waiting 500ms
#
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 570 elements. Proceeding with the first one: <a rel="category tag" href="https://wiwibloggs.com/category/news/eurovision-song-contest-2025/">Eurovision Song Contest 2025</a>
#   - attempting click action
#     - waiting for element to be visible, enabled and stable
#     - element is visible, enabled and stable
#     - scrolling into view if needed
#     - done scrolling
#     - performing click action
#     - click action done
#     - waiting for scheduled navigations to finish
#
# 🔗 Resolved URL: https://eurovisionfun.com/en/2025/05/eurovision-2025-betting-odds-ahead-of-the-second-semi-final-major-shifts-after-semi-final-1/
# 🔗 Resolved URL: chrome-error://chromewebdata/
# 🔗 Resolved URL: chrome-error://chromewebdata/
# 🔗 Resolved URL: chrome-error://chromewebdata/
# 🔗 Resolved URL: chrome-error://chromewebdata/
# 🔗 Resolved URL: chrome-error://chromewebdata/
# 🔗 Resolved URL: https://www.aussievision.net/post/eurovision-2025-odds-who-are-the-favourites-to-win
# 🔗 Resolved URL: https://www.esquire.com/entertainment/music/a64793368/eurovision-2025/
# 🔗 Resolved URL: https://www.sortiraparis.com/en/what-to-see-in-paris/concerts-music-festival/articles/275207-eurovision-2025-10-countries-qualify-for-the-first-semi-final
# 🔗 Resolved URL: chrome-error://chromewebdata/
# 🔗 Resolved URL: https://www.aussievision.net/post/eurovision-2025-odds-who-are-the-favourites-to-win
# 🔗 Resolved URL: https://oneurope.co.uk/countries-a-m/azerbaijan/mamagama-praise-complete-tolerance-in-azerbaijan/
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 26 elements. Proceeding with the first one: <a rel="tag" aria-label="Categoria: Intrattenimento" href="https://www.napolike.com/intrattenimento">Entertainment</a>
#   - attempting click action
#     - waiting for element to be visible, enabled and stable
#     - element is visible, enabled and stable
#     - scrolling into view if needed
#     - done scrolling
#     - performing click action
#     - click action done
#     - waiting for scheduled navigations to finish
#     - navigated to "https://www.napolike.com/intrattenimento"
#
# ✅ Real Article URL: chrome-error://chromewebdata/
# ✅ Real Article URL: https://eurovisionfun.com/en/2025/05/eurovision-2025-betting-odds-ahead-of-the-second-semi-final-major-shifts-after-semi-final-1/
# ✅ Real Article URL: https://oneurope.co.uk/countries-a-m/azerbaijan/mamagama-praise-complete-tolerance-in-azerbaijan/
# ✅ Real Article URL: https://www.aussievision.net/post/eurovision-2025-odds-who-are-the-favourites-to-win
# ✅ Real Article URL: chrome-error://chromewebdata/
# ✅ Real Article URL: https://www.esquire.com/entertainment/music/a64793368/eurovision-2025/
# ✅ Real Article URL: https://www.sortiraparis.com/en/what-to-see-in-paris/concerts-music-festival/articles/275207-eurovision-2025-10-countries-qualify-for-the-first-semi-final
# ✅ Real Article URL: chrome-error://chromewebdata/
# ✅ Real Article URL: chrome-error://chromewebdata/
# ✅ Real Article URL: chrome-error://chromewebdata/
# ✅ Real Article URL: chrome-error://chromewebdata/
# ✅ Real Article URL: https://www.aussievision.net/post/eurovision-2025-odds-who-are-the-favourites-to-win
# 🔗 Resolved URL: https://escdaily.com/category/eurovision-2025/
# ✅ Real Article URL: https://escdaily.com/category/eurovision-2025/
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 37 elements. Proceeding with the first one: <a target="_self" class="sc-f9178328-0 jsleNP" href="https://www.bbc.co.uk/news/articles/cwywjw0y9rvo">What time does the Eurovision 2025 final start an…</a>
#   - attempting click action
#     - waiting for element to be visible, enabled and stable
#     - element is visible, enabled and stable
#     - scrolling into view if needed
#     - done scrolling
#     - performing click action
#     - click action done
#     - waiting for scheduled navigations to finish
#     - navigated to "https://www.bbc.co.uk/news/articles/cwywjw0y9rvo"
#
# 🔗 Resolved URL: https://wiwibloggs.com/2025/05/15/eurovision-2025-semi-final-2-results-qualifiers/284888/
# 🔗 Resolved URL: https://www.gbnews.com/celebrity/bbc-eurovision-2025-finalists-announcement-list-viewers-backlash
# ✅ Real Article URL: https://wiwibloggs.com/2025/05/15/eurovision-2025-semi-final-2-results-qualifiers/284888/
# ✅ Real Article URL: https://www.gbnews.com/celebrity/bbc-eurovision-2025-finalists-announcement-list-viewers-backlash
# 🧭 Navigating to https://news.google.com/rss/articles/CBMifkFVX3lxTE5ncjJxM1NzcmdyaEpyYXI1R3owU3ZsTzFvMUI5b09scEpBRGRKWTR3UzFrOWJmM2ZvRGVNNVBnbmtVYmcyQ1EyTU9Ba2gtZFdEN1VFQlIyZzdMc1pBZVN4bW8zZzdfLXp4Y3lCTW03Sm16bGJmLVBUN2F2NDFIQQ?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMickFVX3lxTE16Y3c1c2hObzhSYTFzMmRkVW9qTmhKbWVSVWlyNWNueV9qLXdjZDNZOERGRjg0TmdNRkFQak5DZDdZcTJraEJMRFFMRERmbGRXZ3pPLUVTSWs5d0dLTEQwVU5xYVhadU1WVkc4RV9JTkowZw?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMikgFBVV95cUxNdXJodUxtWmExMDFCdUx3OGdOR1ExRXdoeXFrMGpuZ1VtblpkU1Y1MWI0YW5ibWdFMmVnRWZRem1mUE00NzZZeHdJVENBSUJtQXFlcGJxMGdkUmtUZm42RE9LdEhmbjR1cldjalFEX0dhaU5VWklHREc4dW9qM2g2NjVVdlBLVEI3NDM5a293SXQwdw?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMipAFBVV95cUxOU3lHcnNqZ19sVU5vZk1OWm1aRkhiMC1FRjYwTEtpcHMtc0hjY2hMMFBoVXFfZ29BcVJzY0VZZ29BcU5EMDdpVFJkcEU5WllwamtJMUtqVXRGZ1YxQUlpLXN5TXRrbkxuMGNhRjJiNkxNMENkUVZFOTl5OVpoRHQ1bUdEeWxkZW9kOFRySmZpNVplWGN3VWlIdkh2bkR5Q2k2a2w5bw?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMipAFBVV95cUxOU3lHcnNqZ19sVU5vZk1OWm1aRkhiMC1FRjYwTEtpcHMtc0hjY2hMMFBoVXFfZ29BcVJzY0VZZ29BcU5EMDdpVFJkcEU5WllwamtJMUtqVXRGZ1YxQUlpLXN5TXRrbkxuMGNhRjJiNkxNMENkUVZFOTl5OVpoRHQ1bUdEeWxkZW9kOFRySmZpNVplWGN3VWlIdkh2bkR5Q2k2a2w5bw?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMijAFBVV95cUxNWTlMTUg3Tk9pSUhlQ2lsVWNzYlgwSFRuU0lQVklpVEZ3aldyWV9tLVhMRG93cThaOWlUbXhLSi1lTjNTYlhZcGlUZUlUcjlRQWh5RmJjUUxYbm1yZlJ2SkYwOGVwOEVObE9zWV81MXp5NkllRnlGc1NnU2E5c2daRzFzMHdnaEE1Q0VGdA?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMioAFBVV95cUxNcndKUTYzLWgyLU9wVnBKNkNIVEFaN0FQdzhqemEzNjlEbWJZSVdnb3k2RDZwZG9kbkx4blFCT1MxSGt1ZFNTVG1kdDU2aHhMVDBkbFZGVjVoUzc3OERoZExpRGx1R2o5ZlhaeTFOelhXNkNSdjd6cUhzSkUxVXlqMHREZGpYWVlIYXFzV0ZHYUdISVFINnNNaGJKcjk0RW9r?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMirAFBVV95cUxQZWdsTEwxdDJGaG1EY0RmTHMtOVlvSFR3RXBPX0QySXJ1VjZ2ZHQ0WHZYYTg2Z3d4N3hJVk9BdDh3ZXNudFpnX05MUnlKdUZaLU80R2lMN1R0NGNMd3B5dUd1eEVHMS1jcUNFR2V1MGxZUHBGQ19ZaU82TTJKZ0Z2ZnZWdUNYMWJiNnN6ZmZyWDRmZlo1NFkyZ3pSeEpmaHZKLWR2X2JCNXdwUGFt?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMifkFVX3lxTE5ncjJxM1NzcmdyaEpyYXI1R3owU3ZsTzFvMUI5b09scEpBRGRKWTR3UzFrOWJmM2ZvRGVNNVBnbmtVYmcyQ1EyTU9Ba2gtZFdEN1VFQlIyZzdMc1pBZVN4bW8zZzdfLXp4Y3lCTW03Sm16bGJmLVBUN2F2NDFIQQ?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMilwFBVV95cUxPcVl3bzhfeHk2WjM5SUNIOHd2d1kxZ3hTTWZZR05mTlE4a1BvZXd0aTJ5b1M1S3R6N2RVS2ZTaWJVQkZiblNsc3dmUzVzcU1nMXEza0ttcEhpc2llUlA5NkVxREw0Q3Y3LW9oOHBtVVlhSl90TTUwYU5BbDg3bDU1cnJxbjFhdlo3aHE1Uk01SWNRdl9WLVk0?oc=5
# 🧭 Navigating to https://news.google.?oc=5
# 🧭 Navigating to https://news.google.?oc=5
# 🧭 Navigating to https://news.google.?oc=5
# 🧭 Navigating to https://news.google.?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMipAFBVV95cUxOU3lHcnNqZ19sVU5vZk1OWm1aRkhiMC1FRjYwTEtpcHMtc0hjY2hMMFBoVXFfZ29BcVJzY0VZZ29BcU5EMDdpVFJkcEU5WllwamtJMUtqVXRGZ1YxQUlpLXN5TXRrbkxuMGNhRjJiNkxNMENkUVZFOTl5OVpoRHQ1bUdEeWxkZW9kOFRySmZpNVplWGN3VWlIdkh2bkR5Q2k2a2w5bw?oc=5
# 🔗 Resolved URL: https://www.napolike.com/intrattenimento
# 🔗 Resolved URL: https://www.bbc.co.uk/news/articles/cwywjw0y9rvo
# ✅ Real Article URL: https://www.napolike.com/intrattenimento
# ✅ Real Article URL: https://www.bbc.co.uk/news/articles/cwywjw0y9rvo
# 🔗 Resolved URL: https://wiwibloggs.com/2025/05/15/eurovision-2025-semi-final-2-results-qualifiers/284888/
# ✅ Real Article URL: https://wiwibloggs.com/2025/05/15/eurovision-2025-semi-final-2-results-qualifiers/284888/
# 🔗 Resolved URL: https://apnews.com/author/jill-lawless
# ✅ Real Article URL: https://apnews.com/author/jill-lawless
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🧭 Navigating to https://news.google.com/rss/articles/CBMijAFBVV95cUxNWTlMTUg3Tk9pSUhlQ2lsVWNzYlgwSFRuU0lQVklpVEZ3aldyWV9tLVhMRG93cThaOWlUbXhLSi1lTjNTYlhZcGlUZUlUcjlRQWh5RmJjUUxYbm1yZlJ2SkYwOGVwOEVObE9zWV81MXp5NkllRnlGc1NnU2E5c2daRzFzMHdnaEE1Q0VGdA?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMipgFBVV95cUxOZzI1dEl4ZUN6TlNrVjRWREtGLTRJRmx4ZWZKbjA1UmExRVpFWTg0bW45YWJOeEFEb1h1dk9yTkE4T05vczV5WXhaNThrS1JDWnJKa0ZvQUwtajA0YTFOZmdwTXB2S3FpcnE2Y0ZwTHNmSk5CcnJOa2xkdnJQM1hDVldCMFdwMTczR1h6Y3NUanR3S0hmWDNza25UWWlQeFkzS01qa19B?oc=5
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🧭 Navigating to https://news.google.com/rss/articles/CBMikgFBVV95cUxOMU9CblMxcTlUZnlzMWY4MUV1X1NDbE16dHdUc214WUt3TDdsVWVXU0k0dGlRaWxqQ28wWlFQbE1WSFBQNnZiZWUzVU1XM3gyUGNjUG1SaEVHOXdTMW1tVy1tdVRBa3VKcWItUENGLVJiV0syNm9iY3JyQ2RybUhRRURKS0RWYllzV1dhRkU0OGlNZw?oc=5
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 35 elements. Proceeding with the first one: <a data-hook="link" href="https://www.aussievision.net" class="blog-navigation-container-color blog-navigation-container-font  blog-navigation-link-hover-color">All Posts</a>
#   - attempting click action
#     2 × waiting for element to be visible, enabled and stable
#       - element is not visible
#     - retrying click action
#     - waiting 20ms
#     2 × waiting for element to be visible, enabled and stable
#       - element is not visible
#     - retrying click action
#       - waiting 100ms
#     3 × waiting for element to be visible, enabled and stable
#       - element is not visible
#     - retrying click action
#       - waiting 500ms
#
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 20 elements. Proceeding with the first one: <a href="https://www.scoresandstats.com/author/kmiller/">Kody Miller</a>
#   - attempting click action
#     - waiting for element to be visible, enabled and stable
#     - element is visible, enabled and stable
#     - scrolling into view if needed
#     - done scrolling
#     - performing click action
#     - click action done
#     - waiting for scheduled navigations to finish
#     - navigated to "https://www.scoresandstats.com/author/kmiller/"
#
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 20 elements. Proceeding with the first one: <a href="/" data-testid="tlogo-home-link" aria-label="The New York Times Home Page">…</a>
#   - attempting click action
#     - waiting for element to be visible, enabled and stable
#     - element is visible, enabled and stable
#     - scrolling into view if needed
#     - done scrolling
#     - performing click action
#     - click action done
#     - waiting for scheduled navigations to finish
#
# 🧭 Navigating to https://news.google.com/rss/articles/CBMimgFBVV95cUxPcl9rZlNTVWhpUVJZSEZMa1B3UDZRSk55MV9nb3FaeVppeGEwYkhiN2F5QjRhRU53elV1Z2s1T2xTcXk3NEVFRmRMaVZYSmpNT253alBnR0s5Wjdlb2I4UG5tbUdRc0swblB3a1ZkbEUxN2xaZldyb2ptYmNXbTlMWUFwaTBTbEFMSmM1TlExbUM4OUJleG8zTlZB?oc=5
# 🔗 Resolved URL: https://eurovoix.com/2025/05/13/the-model-sweden-wins-san-marino-in-cyprus-out-in-eurovision-semi-final-one/
# 🔗 Resolved URL: https://www.scoresandstats.com/author/kmiller/
# ✅ Real Article URL: https://www.scoresandstats.com/author/kmiller/
# ✅ Real Article URL: https://eurovoix.com/2025/05/13/the-model-sweden-wins-san-marino-in-cyprus-out-in-eurovision-semi-final-one/
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 67 elements. Proceeding with the first one: <a href="/betting/" class="t-p-color" data-name="Betting">Betting</a>
#   - attempting click action
#     - waiting for element to be visible, enabled and stable
#     - element is visible, enabled and stable
#     - scrolling into view if needed
#     - done scrolling
#     - performing click action
#     - click action done
#     - waiting for scheduled navigations to finish
#
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🔗 Resolved URL: https://apnews.com/author/jill-lawless
# 🔗 Resolved URL: https://eurovisionfun.com/en/2025/05/eurovision-2025-betting-odds-ahead-of-the-second-semi-final-major-shifts-after-semi-final-1/
# ✅ Real Article URL: https://apnews.com/author/jill-lawless
# 🔗 Resolved URL: https://eurovisionworld.com/esc/eurovision-2025-all-about-the-grand-final
# ✅ Real Article URL: https://eurovisionfun.com/en/2025/05/eurovision-2025-betting-odds-ahead-of-the-second-semi-final-major-shifts-after-semi-final-1/
# ✅ Real Article URL: https://eurovisionworld.com/esc/eurovision-2025-all-about-the-grand-final
# 🔗 Resolved URL: https://www.aussievision.net/post/eurovision-2025-odds-who-are-the-favourites-to-win
# ✅ Real Article URL: https://www.aussievision.net/post/eurovision-2025-odds-who-are-the-favourites-to-win
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🔗 Resolved URL: https://eurovisionworld.com/esc/eurovision-2025-all-about-the-grand-final
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 39 elements. Proceeding with the first one: <a data-hook="link" href="https://www.aussievision.net" class="blog-navigation-container-color blog-navigation-container-font  blog-navigation-link-hover-color">All Posts</a>
#   - attempting click action
#     2 × waiting for element to be visible, enabled and stable
#       - element is not visible
#     - retrying click action
#     - waiting 20ms
#     2 × waiting for element to be visible, enabled and stable
#       - element is not visible
#     - retrying click action
#       - waiting 100ms
#     7 × waiting for element to be visible, enabled and stable
#       - element is not visible
#     - retrying click action
#       - waiting 500ms
#
# ✅ Real Article URL: https://eurovisionworld.com/esc/eurovision-2025-all-about-the-grand-final
# 🔗 Resolved URL: https://www.aussievision.net/post/every-eurovision-song-to-chart-on-the-us-billboard-hot-100
# ✅ Real Article URL: https://www.aussievision.net/post/every-eurovision-song-to-chart-on-the-us-billboard-hot-100
# 🧭 Navigating to https://news.google.com/rss/articles/CBMimgFBVV95cUxNLXhtcTloUTRmTjlDWnQzbG5qaGFVOC1vSG9sREtSN2pEb0xQeGdDVnpIXzZUV21PVlZIS3NXcEZSM243aHJJZzAzOXRZWktaWVUtLXR3LTJ0WUc2VUVPNU43RXpQLWZfUWFsa19WdnRtVjBkUjExSVh1QmJNTDR3bk5FUm9NcTZwZ0dOaWZVcTdIZkRlcmNQZjF3?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMipgFBVV95cUxPdDUyYTZabkZhZXJBVEtMNE53RVd5R1g3bERYYkRhdEhVUS1MX2hXNlduQm5Bd1lJWmpCVFQyeWxWX0p6a25ZQVFnM2xiM2c5Q0V0SHlmb29TaHhzZmYyYkpGVnQ5ZGRZTE93aUNWbHBYWkMyZG53aVVTTGRwZ0Q0NlQyMHVpSzd3dHR6UlhJSlZDYlhoY1lyRjFzYzNSaXFkaUZZVnl3?oc=5
# 🧭 Navigating to https://news.google.?oc=5
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🧭 Navigating to https://news.google.com/rss/articles/CBMipgFBVV95cUxPdDUyYTZabkZhZXJBVEtMNE53RVd5R1g3bERYYkRhdEhVUS1MX2hXNlduQm5Bd1lJWmpCVFQyeWxWX0p6a25ZQVFnM2xiM2c5Q0V0SHlmb29TaHhzZmYyYkpGVnQ5ZGRZTE93aUNWbHBYWkMyZG53aVVTTGRwZ0Q0NlQyMHVpSzd3dHR6UlhJSlZDYlhoY1lyRjFzYzNSaXFkaUZZVnl3?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMipgFBVV95cUxQem5KTlF4U0x3S25ic1Z2NFRwN0lIZk5YMTh5LWp5dEk2MmFwajhtR0Jkd1lFRTZveFhWanMzUGY4Wmk2d3RPcDM5ZHRnUVZBVnBseFpXWW10TDhNUVNqNEQ0MXQ1ak1ZZVQ0YTQzWnNlcFgtUGlwQ19UQVNCSkxPWkRocEdWVXZrbkNSZzRXUWtNM1lEbi16SlU0ZjZzb1p6TlZFWWxn?oc=5
# 🔗 Resolved URL: https://eurovisionworld.com/esc/tonight-semi-final-2-of-the-eurovision-song-contest-2025
# ✅ Real Article URL: https://eurovisionworld.com/esc/tonight-semi-final-2-of-the-eurovision-song-contest-2025
# 🧭 Navigating to https://news.google.com/rss/articles/CBMimgFBVV95cUxPcl9rZlNTVWhpUVJZSEZMa1B3UDZRSk55MV9nb3FaeVppeGEwYkhiN2F5QjRhRU53elV1Z2s1T2xTcXk3NEVFRmRMaVZYSmpNT253alBnR0s5Wjdlb2I4UG5tbUdRc0swblB3a1ZkbEUxN2xaZldyb2ptYmNXbTlMWUFwaTBTbEFMSmM1TlExbUM4OUJleG8zTlZB?oc=5
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🔗 Resolved URL: https://www.napolike.com/intrattenimento
# 🔗 Resolved URL: https://eurovisionfun.com/en/2025/05/eurovision-2025-betting-odds-after-the-second-rehearsals/
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 35 elements. Proceeding with the first one: <a data-hook="link" href="https://www.aussievision.net" class="blog-navigation-container-color blog-navigation-container-font  blog-navigation-link-hover-color">All Posts</a>
#   - attempting click action
#     2 × waiting for element to be visible, enabled and stable
#       - element is not visible
#     - retrying click action
#     - waiting 20ms
#     2 × waiting for element to be visible, enabled and stable
#       - element is not visible
#     - retrying click action
#       - waiting 100ms
#     8 × waiting for element to be visible, enabled and stable
#       - element is not visible
#     - retrying click action
#       - waiting 500ms
#
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🔗 Resolved URL: https://eurovisionworld.com/esc/eurovision-2025-semi-final-1-the-10-songs-qualified-for-the-grand-final
# ✅ Real Article URL: https://www.napolike.com/intrattenimento
# ✅ Real Article URL: https://eurovisionfun.com/en/2025/05/eurovision-2025-betting-odds-after-the-second-rehearsals/
# 🧭 Navigating to https://news.google.com/rss/articles/CBMifEFVX3lxTE1ieWhPZHAxd2ZVT1VRUW5lQ01wbTFhcXM5YXZ6ekYydWVOWHczNzA3X1BsSzV6WEhPUERXaTRuOThpU3Zyc1Bmd2ZpMHQ2b1JJWmVFQ0JZQUpZNTdaR3pjcUtJOE9uRXdoSDUwZXZrWVM4ZXB1Vm0wOTBZdzc?oc=5
# 🔗 Resolved URL: https://www.aussievision.net/post/eurovision-2025-odds-who-are-the-favourites-to-win
# ✅ Real Article URL: https://eurovisionworld.com/esc/eurovision-2025-semi-final-1-the-10-songs-qualified-for-the-grand-final
# 🔗 Resolved URL: https://eurovisionworld.com/esc/tonight-semi-final-1-of-the-eurovision-song-contest-2025
# ✅ Real Article URL: https://www.aussievision.net/post/eurovision-2025-odds-who-are-the-favourites-to-win
# ✅ Real Article URL: https://eurovisionworld.com/esc/tonight-semi-final-1-of-the-eurovision-song-contest-2025
# 🧭 Navigating to https://news.google.?oc=5
# 🔗 Resolved URL: https://news.paddypower.com/television/2025/05/15/eurovision-odds-semi-final-2-thursday-night-best-bets-odds-may-15-2025/
# ✅ Real Article URL: https://news.paddypower.com/television/2025/05/15/eurovision-odds-semi-final-2-thursday-night-best-bets-odds-may-15-2025/
# 🧭 Navigating to https://news.google.com/rss/articles/CBMijgFBVV95cUxNZFNPQWNOWTYxLWd4MGtXTUVPbURrLWZJSHRYb29nMUQ4T2stb0dDTGxxNE9XUTRLM1NZUzJET3J2dnAwRV9yVTlhZmhMNURoMW5OWVlIM1VYUFJSd3hRanBmY3M1bVZSTksycnQzVWxjbDZZdTFaY0w1ZG5FYktUTWdwNlU5VEZqbS1OVjhn?oc=5
# 🧭 Navigating to https://news.google....?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMipgFBVV95cUxOZzI1dEl4ZUN6TlNrVjRWREtGLTRJRmx4ZWZKbjA1UmExRVpFWTg0bW45YWJOeEFEb1h1dk9yTkE4T05vczV5WXhaNThrS1JDWnJKa0ZvQUwtajA0YTFOZmdwTXB2S3FpcnE2Y0ZwTHNmSk5CcnJOa2xkdnJQM1hDVldCMFdwMTczR1h6Y3NUanR3S0hmWDNza25UWWlQeFkzS01qa19B?oc=5
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 611 elements. Proceeding with the first one: <a rel="category tag" href="https://wiwibloggs.com/category/news/eurovision-song-contest-2025/">Eurovision Song Contest 2025</a>
#   - attempting click action
#     - waiting for element to be visible, enabled and stable
#     - element is visible, enabled and stable
#     - scrolling into view if needed
#     - done scrolling
#     - performing click action
#     - click action done
#     - waiting for scheduled navigations to finish
#
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 611 elements. Proceeding with the first one: <a rel="category tag" href="https://wiwibloggs.com/category/news/eurovision-song-contest-2025/">Eurovision Song Contest 2025</a>
#   - attempting click action
#     - waiting for element to be visible, enabled and stable
#     - element is visible, enabled and stable
#     - scrolling into view if needed
#     - done scrolling
#     - performing click action
#     - click action done
#     - waiting for scheduled navigations to finish
#
# 🧭 Navigating to https://news.google.com/rss/articles/CBMiZ0FVX3lxTFBNWDlmemVrNElVYnk1N3ljTDk2NXFkR0h0MjBxNldIYktuVDI2WTFkNHFSbDZHaWFzLTZBUDEzTHZrVmhmNk92VmZlbFkzLUxkRkpIZVNPWmFjRVhZR0hROXliMFVCRTA?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMiogFBVV95cUxQWllvTmRRazdZNGNiN1dIRFpGZUFWNGZ5dlUzY0FwM1dHYUtQRWFRVXdwTjh1SkxDYzQxUmdSVmoxdkRVVWlvajZPMmVpV2lvelJEeDI3OE85czZPd05sMDUtWEZWU0xEaUR0Um5mZXZPaWxKT2ZYdE1mUWpFYXhBV2ZGMnozakdWR3FMMGc4VXpUdm1aQUdEc2xXSlB3cmFHakE?oc=5
# 🧭 Navigating to https://news.google.?oc=5
# 🧭 Navigating to https://news.google.?oc=5
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🔗 Resolved URL: https://talksport.com/betting/3139411/eurovision-betting-odds-2025/
# 🔗 Resolved URL: https://wiwibloggs.com/2025/05/13/eurovision-song-contest-2025-semi-final-1-results-qualifiers/284822/#google_vignette
# ✅ Real Article URL: https://talksport.com/betting/3139411/eurovision-betting-odds-2025/
# 🔗 Resolved URL: https://eurovisionworld.com/esc/eurovision-2025-draws-for-the-running-order-in-the-grand-final
# ✅ Real Article URL: https://wiwibloggs.com/2025/05/13/eurovision-song-contest-2025-semi-final-1-results-qualifiers/284822/#google_vignette
# 🔗 Resolved URL: https://eurovisionfun.com/en/2025/05/eurovision-2025-betting-odds-after-the-second-rehearsals/
# ✅ Real Article URL: https://eurovisionworld.com/esc/eurovision-2025-draws-for-the-running-order-in-the-grand-final
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 45 elements. Proceeding with the first one: <a data-hook="link" href="https://www.aussievision.net" class="blog-navigation-container-color blog-navigation-container-font  blog-navigation-link-hover-color">All Posts</a>
#   - attempting click action
#     2 × waiting for element to be visible, enabled and stable
#       - element is not visible
#     - retrying click action
#     - waiting 20ms
#     2 × waiting for element to be visible, enabled and stable
#       - element is not visible
#     - retrying click action
#       - waiting 100ms
#     8 × waiting for element to be visible, enabled and stable
#       - element is not visible
#     - retrying click action
#       - waiting 500ms
#
# ✅ Real Article URL: https://eurovisionfun.com/en/2025/05/eurovision-2025-betting-odds-after-the-second-rehearsals/
# 🔗 Resolved URL: https://eurovisionworld.com/esc/eurovision-2025-semi-final-2-the-10-songs-qualified-for-the-grand-final
# 🔗 Resolved URL: https://eurovisionworld.com/esc/eurovision-2025-semi-final-2-the-10-songs-qualified-for-the-grand-final
# 🔗 Resolved URL: https://www.aussievision.net/post/sbs-broadcast-when-and-where-can-i-watch-eurovision-2025-in-australia
# ✅ Real Article URL: https://eurovisionworld.com/esc/eurovision-2025-semi-final-2-the-10-songs-qualified-for-the-grand-final
# ✅ Real Article URL: https://www.aussievision.net/post/sbs-broadcast-when-and-where-can-i-watch-eurovision-2025-in-australia
# ✅ Real Article URL: https://eurovisionworld.com/esc/eurovision-2025-semi-final-2-the-10-songs-qualified-for-the-grand-final
# 🧭 Navigating to https://news.google.com/rss/articles/CBMihwFBVV95cUxQaXlvUzlTaUYzRERXT1AzeGs4MEI2V2dYenRVWmZFek13Z2d2ek02ZEVIdXRlOS1VdEh1MUpwbUR2ODJPbkFBc1NLY3pveFpfZm0wejN4Y3haeGVtQ2JocmphZ3F4bXNWX0RqRnptU2xlYmFoNmxnNERiZk1NYlM4anh5OGhRNjQ?oc=5
# 🧭 Navigating to https://news.google.?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMimgFBVV95cUxNLXhtcTloUTRmTjlDWnQzbG5qaGFVOC1vSG9sREtSN2pEb0xQeGdDVnpIXzZUV21PVlZIS3NXcEZSM243aHJJZzAzOXRZWktaWVUtLXR3LTJ0WUc2VUVPNU43RXpQLWZfUWFsa19WdnRtVjBkUjExSVh1QmJNTDR3bk5FUm9NcTZwZ0dOaWZVcTdIZkRlcmNQZjF3?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMifkFVX3lxTE5ncjJxM1NzcmdyaEpyYXI1R3owU3ZsTzFvMUI5b09scEpBRGRKWTR3UzFrOWJmM2ZvRGVNNVBnbmtVYmcyQ1EyTU9Ba2gtZFdEN1VFQlIyZzdMc1pBZVN4bW8zZzdfLXp4Y3lCTW03Sm16bGJmLVBUN2F2NDFIQQ?oc=5
# 🧭 Navigating to https://news.google....?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMie0FVX3lxTE5mazZ5VVFzeXE5ZjNISUtvWnhHMHJaNTBUVFl2VWZOcllIZnFYRTA2WlVzVU9MbENfQm5kOFJvQVlfU3FuUVRFT3FURmNaVWFHcGhOcWR6N19zQUhIVTNyZTkteDJHSGlVTU15SFpPck5ZUFMyU1M3OGwwRQ?oc=5
# 🧭 Navigating to https://news.google.?oc=5
# 🔗 Resolved URL: https://www.abc.net.au/news/yasmin-jeffery/10750568
# ✅ Real Article URL: https://www.abc.net.au/news/yasmin-jeffery/10750568
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🔗 Resolved URL: https://eurovisionfun.com/en/2025/05/eurovision-2025-betting-odds-ahead-of-the-second-semi-final-major-shifts-after-semi-final-1/
# 🔗 Resolved URL: https://rubryka.com/en/2025/05/14/ukrayinskyj-gurt-ziferblat-projshov-do-finalu-yevrobachennya-2025/
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# ✅ Real Article URL: https://rubryka.com/en/2025/05/14/ukrayinskyj-gurt-ziferblat-projshov-do-finalu-yevrobachennya-2025/
# ✅ Real Article URL: https://eurovisionfun.com/en/2025/05/eurovision-2025-betting-odds-ahead-of-the-second-semi-final-major-shifts-after-semi-final-1/
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🔗 Resolved URL: https://eurovisionworld.com/esc/eurovision-2025-semi-final-1-the-10-songs-qualified-for-the-grand-final
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 58 elements. Proceeding with the first one: <a rel="category tag" href="https://escdaily.com/category/eurovision-2025/">Eurovision 2025</a>
#   - attempting click action
#     - waiting for element to be visible, enabled and stable
#     - element is visible, enabled and stable
#     - scrolling into view if needed
#     - done scrolling
#     - performing click action
#     - click action done
#     - waiting for scheduled navigations to finish
#     - navigated to "https://escdaily.com/category/eurovision-2025/"
#
# 🔗 Resolved URL: https://www.oddschecker.com/insight/tv/20250516-eurovision-bookies-top-10-bookmakers-taking-bets-on-eurovision-song-contest
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 20 elements. Proceeding with the first one: <a href="#img-1" tabindex="-1" aria-hidden="true" data-ignore="global-link-styling" class="open-lightbox dcr-13fd1ms">…</a>
#   - attempting click action
#     2 × waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <iframe id="sp_message_iframe_1290709" title="The Guardian consent message" src="https://sourcepoint.theguardian.com/index.html?hasCsp=true&message_id=1290709&consentUUID=null&consent_origin=https%3A%2F%2Fsourcepoint.theguardian.com%2Fconsent%2Ftcfv2&preload_message=true&version=v1"></iframe> from <div id="sp_message_container_1290709">…</div> subtree intercepts pointer events
#     - retrying click action
#     - waiting 20ms
#     2 × waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <iframe id="sp_message_iframe_1290709" title="The Guardian consent message" src="https://sourcepoint.theguardian.com/index.html?hasCsp=true&message_id=1290709&consentUUID=null&consent_origin=https%3A%2F%2Fsourcepoint.theguardian.com%2Fconsent%2Ftcfv2&preload_message=true&version=v1"></iframe> from <div id="sp_message_container_1290709">…</div> subtree intercepts pointer events
#     - retrying click action
#       - waiting 100ms
#     7 × waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <iframe id="sp_message_iframe_1290709" title="The Guardian consent message" src="https://sourcepoint.theguardian.com/index.html?hasCsp=true&message_id=1290709&consentUUID=null&consent_origin=https%3A%2F%2Fsourcepoint.theguardian.com%2Fconsent%2Ftcfv2&preload_message=true&version=v1"></iframe> from <div id="sp_message_container_1290709">…</div> subtree intercepts pointer events
#     - retrying click action
#       - waiting 500ms
#
# ✅ Real Article URL: https://eurovisionworld.com/esc/eurovision-2025-semi-final-1-the-10-songs-qualified-for-the-grand-final
# 🔗 Resolved URL: https://escdaily.com/category/eurovision-2025/
# ✅ Real Article URL: https://www.oddschecker.com/insight/tv/20250516-eurovision-bookies-top-10-bookmakers-taking-bets-on-eurovision-song-contest
# ✅ Real Article URL: https://escdaily.com/category/eurovision-2025/
# 🔗 Resolved URL: https://www.theguardian.com/tv-and-radio/2025/may/13/10-best-eurovision-songs-of-2025
# ✅ Real Article URL: https://www.theguardian.com/tv-and-radio/2025/may/13/10-best-eurovision-songs-of-2025
# 🧭 Navigating to https://news.google.com/rss/articles/CBMiiAFBVV95cUxNSHVuZGEwSUNuQnJhelJMNUY0MXpCaHpXX1BpZ1haNThjbjhxUmkxbC1xWjByekdXYzhhN05VU0NlVFgzRWU0WHpTaDlMR3lrZzNtWl9KTC15YllkLW10bkxwaGtLckU0aEQ4bmVBanVsaHY0d094Y0xKNUt5UlFfZGNyRVhLSWpX?oc=5
# 🔗 Resolved URL: https://wiwibloggs.com/2025/05/13/eurovision-song-contest-2025-semi-final-1-results-qualifiers/284822/
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# ✅ Real Article URL: https://wiwibloggs.com/2025/05/13/eurovision-song-contest-2025-semi-final-1-results-qualifiers/284822/
# 🔗 Resolved URL: https://eurovisionworld.com/eurovision/2025/semi-final-1
# 🔗 Resolved URL: https://wiwibloggs.com/2025/05/13/eurovision-song-contest-2025-semi-final-1-results-qualifiers/284822/
# ✅ Real Article URL: https://eurovisionworld.com/eurovision/2025/semi-final-1
# ✅ Real Article URL: https://wiwibloggs.com/2025/05/13/eurovision-song-contest-2025-semi-final-1-results-qualifiers/284822/
# 🧭 Navigating to https://news.google.com/rss/articles/CBMirAFBVV95cUxNX2pEZUE2NlNZS1lVUi1fZEZkcmhvSGRXMWU5a1lWeGlYcW5ZNjJsMC15RU9OUkp0MVZLdVVRV1k0UXo1aVIwckZGbzZFUVVfWlpCQzUyQ1lLS3VXR0d1MHJydWxpQzRwS1ZYaGVxVVRtZ2tCelRxNVNjaWhrR2JxX284d2d4dDAtTVhScDJKaUJiX2dsZGZ4NF90SkNzaUg3VzVDSkp3dWRCRGJS?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMipgFBVV95cUxPdDUyYTZabkZhZXJBVEtMNE53RVd5R1g3bERYYkRhdEhVUS1MX2hXNlduQm5Bd1lJWmpCVFQyeWxWX0p6a25ZQVFnM2xiM2c5Q0V0SHlmb29TaHhzZmYyYkpGVnQ5ZGRZTE93aUNWbHBYWkMyZG53aVVTTGRwZ0Q0NlQyMHVpSzd3dHR6UlhJSlZDYlhoY1lyRjFzYzNSaXFkaUZZVnl3?oc=5
# 🔗 Resolved URL: https://www.nytimes.com/2025/05/16/arts/television/how-to-watch-eurovision-final-running-order.html
# 🧭 Navigating to https://news.google.com/rss/articles/CBMikwFBVV95cUxOc0Nqbi1NSGwxZ2E0QU1WZHdETlRPVXF5aWJpQ1JYY25RMS1GejNGdUVVSURYTTVTX3gyeGZ6WXc2ZGZtaTYweTAyTFhHSGQxQjhJYTJKSjVOQnpJanE1cTZHUVh0eUFqQWdRLUdlZ2tEaHRCMnhxMDI1d0tBdjhTRzF1VlhMUy1Kb1ZGRXdTa0VfQ1E?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMikwFBVV95cUxOc0Nqbi1NSGwxZ2E0QU1WZHdETlRPVXF5aWJpQ1JYY25RMS1GejNGdUVVSURYTTVTX3gyeGZ6WXc2ZGZtaTYweTAyTFhHSGQxQjhJYTJKSjVOQnpJanE1cTZHUVh0eUFqQWdRLUdlZ2tEaHRCMnhxMDI1d0tBdjhTRzF1VlhMUy1Kb1ZGRXdTa0VfQ1E?oc=5
# ✅ Real Article URL: https://www.nytimes.com/2025/05/16/arts/television/how-to-watch-eurovision-final-running-order.html
# 🧭 Navigating to https://news.google....?oc=5
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🔗 Resolved URL: https://www.bbc.co.uk/news/articles/cwywjw0y9rvo
# ✅ Real Article URL: https://www.bbc.co.uk/news/articles/cwywjw0y9rvo
# 🔗 Resolved URL: https://eurovisionworld.com/esc/eurovision-2025-draws-for-the-running-order-in-the-grand-final
# 🧭 Navigating to https://news.google.com/rss/articles/CBMickFVX3lxTE16Y3c1c2hObzhSYTFzMmRkVW9qTmhKbWVSVWlyNWNueV9qLXdjZDNZOERGRjg0TmdNRkFQak5DZDdZcTJraEJMRFFMRERmbGRXZ3pPLUVTSWs5d0dLTEQwVU5xYVhadU1WVkc4RV9JTkowZw?oc=5
# ✅ Real Article URL: https://eurovisionworld.com/esc/eurovision-2025-draws-for-the-running-order-in-the-grand-final
# 🧭 Navigating to https://news.google.com/rss/articles/CBMijAFBVV95cUxNWTlMTUg3Tk9pSUhlQ2lsVWNzYlgwSFRuU0lQVklpVEZ3aldyWV9tLVhMRG93cThaOWlUbXhLSi1lTjNTYlhZcGlUZUlUcjlRQWh5RmJjUUxYbm1yZlJ2SkYwOGVwOEVObE9zWV81MXp5NkllRnlGc1NnU2E5c2daRzFzMHdnaEE1Q0VGdA?oc=5
# 🧭 Navigating to https://news.google.?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMikgFBVV95cUxOMU9CblMxcTlUZnlzMWY4MUV1X1NDbE16dHdUc214WUt3TDdsVWVXU0k0dGlRaWxqQ28wWlFQbE1WSFBQNnZiZWUzVU1XM3gyUGNjUG1SaEVHOXdTMW1tVy1tdVRBa3VKcWItUENGLVJiV0syNm9iY3JyQ2RybUhRRURKS0RWYllzV1dhRkU0OGlNZw?oc=5
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 48 elements. Proceeding with the first one: <a href="/" data-testid="tlogo-home-link" aria-label="The New York Times Home Page">…</a>
#   - attempting click action
#     2 × waiting for element to be visible, enabled and stable
#       - element is not visible
#     - retrying click action
#     - waiting 20ms
#     2 × waiting for element to be visible, enabled and stable
#       - element is not visible
#     - retrying click action
#       - waiting 100ms
#     4 × waiting for element to be visible, enabled and stable
#       - element is not visible
#     - retrying click action
#       - waiting 500ms
#     - waiting for element to be visible, enabled and stable
#
# 🧭 Navigating to https://news.google.com/rss/articles/CBMifkFVX3lxTE5ncjJxM1NzcmdyaEpyYXI1R3owU3ZsTzFvMUI5b09scEpBRGRKWTR3UzFrOWJmM2ZvRGVNNVBnbmtVYmcyQ1EyTU9Ba2gtZFdEN1VFQlIyZzdMc1pBZVN4bW8zZzdfLXp4Y3lCTW03Sm16bGJmLVBUN2F2NDFIQQ?oc=5
# ...
# ✅ Real Article URL: https://eurovisionfun.com/en/2025/05/eurovision-2025-betting-odds-ahead-of-the-second-semi-final-major-shifts-after-semi-final-1/
# 🧭 Navigating to https://news.google.com/rss/articles/CBMikwFBVV95cUxOc0Nqbi1NSGwxZ2E0QU1WZHdETlRPVXF5aWJpQ1JYY25RMS1GejNGdUVVSURYTTVTX3gyeGZ6WXc2ZGZtaTYweTAyTFhHSGQxQjhJYTJKSjVOQnpJanE1cTZHUVh0eUFqQWdRLUdlZ2tEaHRCMnhxMDI1d0tBdjhTRzF1VlhMUy1Kb1ZGRXdTa0VfQ1E?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMijgFBVV95cUxNMjNjRHZsbmIySFRhaklMYmlwWTVzV3oxT0pPeGFqcGNYVEFiOUtPMnk3MjN5RWwyekpXRU1CSHMxMFRPRTYwT2hOY2VFMVV0THFNOHdPMjl4dEs2U1NXbVVGT2pUSFZxRXFTaDlsb0dzenM3bVg3ZEtiS3hlTG5EUXh2UVZod2tXa2tYbHJB?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMiiAFBVV95cUxNSHVuZGEwSUNuQnJhelJMNUY0MXpCaHpXX1BpZ1haNThjbjhxUmkxbC1xWjByekdXYzhhN05VU0NlVFgzRWU0WHpTaDlMR3lrZzNtWl9KTC15YllkLW10bkxwaGtLckU0aEQ4bmVBanVsaHY0d094Y0xKNUt5UlFfZGNyRVhLSWpX?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMimgFBVV95cUxPcl9rZlNTVWhpUVJZSEZMa1B3UDZRSk55MV9nb3FaeVppeGEwYkhiN2F5QjRhRU53elV1Z2s1T2xTcXk3NEVFRmRMaVZYSmpNT253alBnR0s5Wjdlb2I4UG5tbUdRc0swblB3a1ZkbEUxN2xaZldyb2ptYmNXbTlMWUFwaTBTbEFMSmM1TlExbUM4OUJleG8zTlZB?oc=5
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🧭 Navigating to https://news.google.com/rss/articles/CBMipgFBVV95cUxPdDUyYTZabkZhZXJBVEtMNE53RVd5R1g3bERYYkRhdEhVUS1MX2hXNlduQm5Bd1lJWmpCVFQyeWxWX0p6a25ZQVFnM2xiM2c5Q0V0SHlmb29TaHhzZmYyYkpGVnQ5ZGRZTE93aUNWbHBYWkMyZG53aVVTTGRwZ0Q0NlQyMHVpSzd3dHR6UlhJSlZDYlhoY1lyRjFzYzNSaXFkaUZZVnl3?oc=5
# 🔗 Resolved URL: https://english.radio.cz/adonxs-sings-czechia-basel-what-are-his-chances-eurovision-2025-8851048
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🧭 Navigating to https://news.google.com/rss/articles/CBMiVEFVX3lxTE95bkU2cjlZenJVWHJTM214YVJ5MkE4QmNyOElUcHRqUjFTZWhvY2lCbUxNcFdQSG91QzVGWVFoSzIzajNxTmt1eTR3alBSeE1pSUQ5Ng?oc=5
# ✅ Real Article URL: https://english.radio.cz/adonxs-sings-czechia-basel-what-are-his-chances-eurovision-2025-8851048
# 🔗 Resolved URL: https://eurovisionworld.com/esc/tonight-semi-final-1-of-the-eurovision-song-contest-2025
# 🧭 Navigating to https://news.google.?oc=5
# ✅ Real Article URL: https://eurovisionworld.com/esc/tonight-semi-final-1-of-the-eurovision-song-contest-2025
# 🔗 Resolved URL: https://www.manchestereveningnews.co.uk/
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 109 elements. Proceeding with the first one: <a href="https://www.npr.org/series/pop-culture-happy-hour">…</a>
#   - attempting click action
#     2 × waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <div class="onetrust-pc-dark-filter ot-fade-in"></div> from <div id="onetrust-consent-sdk">…</div> subtree intercepts pointer events
#     - retrying click action
#     - waiting 20ms
#     2 × waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <div class="onetrust-pc-dark-filter ot-fade-in"></div> from <div id="onetrust-consent-sdk">…</div> subtree intercepts pointer events
#     - retrying click action
#       - waiting 100ms
#     7 × waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <div class="onetrust-pc-dark-filter ot-fade-in"></div> from <div id="onetrust-consent-sdk">…</div> subtree intercepts pointer events
#     - retrying click action
#       - waiting 500ms
#
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# ✅ Real Article URL: https://www.manchestereveningnews.co.uk/
# 🔗 Resolved URL: https://eurovisionworld.com/esc/eurovision-2025-draws-for-the-running-order-in-the-grand-final
# 🔗 Resolved URL: https://www.npr.org/2025/05/15/nx-s1-5392026/eurovision-2025-best-songs
# ✅ Real Article URL: https://eurovisionworld.com/esc/eurovision-2025-draws-for-the-running-order-in-the-grand-final
# ✅ Real Article URL: https://www.npr.org/2025/05/15/nx-s1-5392026/eurovision-2025-best-songs
# 🔗 Resolved URL: https://eurovisionfun.com/en/2025/05/eurovision-2025-betting-odds-after-the-second-rehearsals/
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# ✅ Real Article URL: https://eurovisionfun.com/en/2025/05/eurovision-2025-betting-odds-after-the-second-rehearsals/
# 🔗 Resolved URL: https://eurovisionworld.com/esc/eurovision-2025-running-order-for-the-grand-final
# ✅ Real Article URL: https://eurovisionworld.com/esc/eurovision-2025-running-order-for-the-grand-final
# 🔗 Resolved URL: https://www.bbc.co.uk/news/articles/cwywjw0y9rvo
# ✅ Real Article URL: https://www.bbc.co.uk/news/articles/cwywjw0y9rvo
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 717 elements. Proceeding with the first one: <a rel="category tag" href="https://wiwibloggs.com/category/news/eurovision-song-contest-2025/">Eurovision Song Contest 2025</a>
#   - attempting click action
#     - waiting for element to be visible, enabled and stable
#     - element is visible, enabled and stable
#     - scrolling into view if needed
#     - done scrolling
#     - performing click action
#     - click action done
#     - waiting for scheduled navigations to finish
#
# 🔗 Resolved URL: https://www.bbc.com/news/live/cvg7wp2jey6t
# ✅ Real Article URL: https://www.bbc.com/news/live/cvg7wp2jey6t
# 🧭 Navigating to https://news.google.com/rss/articles/CBMipgFBVV95cUxOZzI1dEl4ZUN6TlNrVjRWREtGLTRJRmx4ZWZKbjA1UmExRVpFWTg0bW45YWJOeEFEb1h1dk9yTkE4T05vczV5WXhaNThrS1JDWnJKa0ZvQUwtajA0YTFOZmdwTXB2S3FpcnE2Y0ZwTHNmSk5CcnJOa2xkdnJQM1hDVldCMFdwMTczR1h6Y3NUanR3S0hmWDNza25UWWlQeFkzS01qa19B?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMiXEFVX3lxTE5NbEc1Vk8xMEhfZmxvNndFY2d6eERKakM2bjRJdmsyWWRwejlLTmdXeTBwUWlKRDBSZTlnNWV1V0xnOU1mc01CQ1VreU04RmkySDV0MVZaQXhSYjZl?oc=5
# 🔗 Resolved URL: https://wiwibloggs.com/category/news/eurovision-song-contest-2025/
# 🔗 Resolved URL: https://wiwibloggs.com/category/news/eurovision-song-contest-2025/
# 🧭 Navigating to https://news.google.com/rss/articles/CBMikwFBVV95cUxOc0Nqbi1NSGwxZ2E0QU1WZHdETlRPVXF5aWJpQ1JYY25RMS1GejNGdUVVSURYTTVTX3gyeGZ6WXc2ZGZtaTYweTAyTFhHSGQxQjhJYTJKSjVOQnpJanE1cTZHUVh0eUFqQWdRLUdlZ2tEaHRCMnhxMDI1d0tBdjhTRzF1VlhMUy1Kb1ZGRXdTa0VfQ1E?oc=5
# ✅ Real Article URL: https://wiwibloggs.com/category/news/eurovision-song-contest-2025/
# ✅ Real Article URL: https://wiwibloggs.com/category/news/eurovision-song-contest-2025/
# 🧭 Navigating to https://news.google.com/rss/articles/CBMiqwFBVV95cUxQdm1LMEMyME1pYU5Qc2MwT2F4R2h1WjI4ODBHdUJwQi1zazZEVUhJTC11QnppMGJvQ083UVo5SnlnU2wyai1tb0h3RW5WUkZJUXNPdmRBWlFQZjh6Rm5xRmZROWpveUNFUkQxekNwTS15bE83QXFmanhQVHhEN0pvZHBhY05kamo1aFl2TWJnUmhWRmlxei0tbXdiUmhJZFY1M204RWduUXJ3Zms?oc=5
# 🔗 Resolved URL: https://www.bbc.com/news/live/cvg7wp2jey6t
# ✅ Real Article URL: https://www.bbc.com/news/live/cvg7wp2jey6t
# 🧭 Navigating to https://news.google.com/rss/articles/CBMikwFBVV95cUxOc0Nqbi1NSGwxZ2E0QU1WZHdETlRPVXF5aWJpQ1JYY25RMS1GejNGdUVVSURYTTVTX3gyeGZ6WXc2ZGZtaTYweTAyTFhHSGQxQjhJYTJKSjVOQnpJanE1cTZHUVh0eUFqQWdRLUdlZ2tEaHRCMnhxMDI1d0tBdjhTRzF1VlhMUy1Kb1ZGRXdTa0VfQ1E?oc=5
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🧭 Navigating to https://news.google....?oc=5
# 🔗 Resolved URL: https://eurovisionworld.com/esc/eurovision-2025-semi-final-2-the-10-songs-qualified-for-the-grand-final
# ✅ Real Article URL: https://eurovisionworld.com/esc/eurovision-2025-semi-final-2-the-10-songs-qualified-for-the-grand-final
# 🔗 Resolved URL: https://talksport.com/betting/
# ✅ Real Article URL: https://talksport.com/betting/
# 🔗 Resolved URL: https://edition.cnn.com/2025/05/08/europe/new-pope-conclave-white-smoke-vatican-intl
# 🔗 Resolved URL: https://wiwibloggs.com/2025/05/16/eurovision-2025-grand-final-running-order-norway-opens-albania-closes/284895/
# ✅ Real Article URL: https://edition.cnn.com/2025/05/08/europe/new-pope-conclave-white-smoke-vatican-intl
# ✅ Real Article URL: https://wiwibloggs.com/2025/05/16/eurovision-2025-grand-final-running-order-norway-opens-albania-closes/284895/
# 🔗 Resolved URL: https://wiwibloggs.com/category/news/
# ✅ Real Article URL: https://wiwibloggs.com/category/news/
# 🔗 Resolved URL: https://wiwibloggs.com/category/news/eurovision-song-contest-2025/
# ✅ Real Article URL: https://wiwibloggs.com/category/news/eurovision-song-contest-2025/
# 🧭 Navigating to https://news.google.com/rss/articles/CBMihwFBVV95cUxOVy1JWXdQeHlpRDJUOUtMaVdfY1lnaHVqOFVLR3R6dlctaWcxcHJTZkpQbjdUcG9mOGN2Z3dXU2pBVzVzd2RrdXZOeWZmNmVDelNVNmU4UVljejNDaWhzbnZJbWIyQXh3UVVlY2p2OVEzT3ludnR1YVdyMW5fY3NnUXRuNTBPS1U?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMifkFVX3lxTE5ncjJxM1NzcmdyaEpyYXI1R3owU3ZsTzFvMUI5b09scEpBRGRKWTR3UzFrOWJmM2ZvRGVNNVBnbmtVYmcyQ1EyTU9Ba2gtZFdEN1VFQlIyZzdMc1pBZVN4bW8zZzdfLXp4Y3lCTW03Sm16bGJmLVBUN2F2NDFIQQ?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMie0FVX3lxTE5mazZ5VVFzeXE5ZjNISUtvWnhHMHJaNTBUVFl2VWZOcllIZnFYRTA2WlVzVU9MbENfQm5kOFJvQVlfU3FuUVRFT3FURmNaVWFHcGhOcWR6N19zQUhIVTNyZTkteDJHSGlVTU15SFpPck5ZUFMyU1M3OGwwRQ?oc=5
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🔗 Resolved URL: https://eurovisionworld.com/esc/eurovision-2025-semi-final-1-the-10-songs-qualified-for-the-grand-final
# 🧭 Navigating to https://news.google.?oc=5
# ✅ Real Article URL: https://eurovisionworld.com/esc/eurovision-2025-semi-final-1-the-10-songs-qualified-for-the-grand-final
# 🧭 Navigating to https://news.google.?oc=5
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 33 elements. Proceeding with the first one: <a class="Link " href="https://apnews.com/author/jill-lawless">…</a>
#   - attempting click action
#     - waiting for element to be visible, enabled and stable
#     - element is visible, enabled and stable
#     - scrolling into view if needed
#     - done scrolling
#
# 🔗 Resolved URL: https://www.bbc.co.uk/news/live/c74n9n5l1nxt
# 🔗 Resolved URL: https://en.ara.cat/
# ✅ Real Article URL: https://www.bbc.co.uk/news/live/c74n9n5l1nxt
# ✅ Real Article URL: https://en.ara.cat/
# 🔗 Resolved URL: https://escdaily.com/category/eurovision-2025/
# ✅ Real Article URL: https://escdaily.com/category/eurovision-2025/
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🔗 Resolved URL: https://betting.betfair.com/specials/eurovision-song-contest/eurovision-betting-tips-slovenia-to-stumble-in-semi-final-1-and-back-france-for-glory-120525-140.html
# ✅ Real Article URL: https://betting.betfair.com/specials/eurovision-song-contest/eurovision-betting-tips-slovenia-to-stumble-in-semi-final-1-and-back-france-for-glory-120525-140.html
# 🧭 Navigating to https://news.google.com/rss/articles/CBMiVEFVX3lxTE95bkU2cjlZenJVWHJTM214YVJ5MkE4QmNyOElUcHRqUjFTZWhvY2lCbUxNcFdQSG91QzVGWVFoSzIzajNxTmt1eTR3alBSeE1pSUQ5Ng?oc=5
# 🔗 Resolved URL: https://www.thepinknews.com/culture/music/
# ✅ Real Article URL: https://www.thepinknews.com/culture/music/
# 🔗 Resolved URL: https://apnews.com/article/eurovision-basel-semifinal-results-eliminations-44e0c8fd8d3b4240c5928aaea6bf64c4
# 🔗 Resolved URL: https://wiwibloggs.com/category/news/eurovision-song-contest-2025/
# 🔗 Resolved URL: https://wiwibloggs.com/category/news/eurovision-song-contest-2025/
# ✅ Real Article URL: https://wiwibloggs.com/category/news/eurovision-song-contest-2025/
# ✅ Real Article URL: https://apnews.com/article/eurovision-basel-semifinal-results-eliminations-44e0c8fd8d3b4240c5928aaea6bf64c4
# ✅ Real Article URL: https://wiwibloggs.com/category/news/eurovision-song-contest-2025/
# 🧭 Navigating to https://news.google.com/rss/articles/CBMilAFBVV95cUxNMlZDSy1OajlMQi1SUGZxWGJlZ3JxOFp3akwxSy1rR3U3RTBqZklVQzVINzk0ek9EVEdkalZqdzIwRjFDU05nMFJKZ1RYLXJEZWFVeGdpZXJXcHFyNkR2cTRuLUZ3ZXNFdVZpLWlGbG4wZm05WmhWbmdaOXBCVG1aTHZFVzNhVFNFMi10TG9pLUp6ZkZm?oc=5
# 🧭 Navigating to https://news.google.com/rss/articles/CBMikgFBVV95cUxOMU9CblMxcTlUZnlzMWY4MUV1X1NDbE16dHdUc214WUt3TDdsVWVXU0k0dGlRaWxqQ28wWlFQbE1WSFBQNnZiZWUzVU1XM3gyUGNjUG1SaEVHOXdTMW1tVy1tdVRBa3VKcWItUENGLVJiV0syNm9iY3JyQ2RybUhRRURKS0RWYllzV1dhRkU0OGlNZw?oc=5
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🔗 Resolved URL: https://eurovisionworld.com/esc/eurovision-2025-all-about-the-grand-final
# ✅ Real Article URL: https://eurovisionworld.com/esc/eurovision-2025-all-about-the-grand-final
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🔗 Resolved URL: chrome-error://chromewebdata/
# ✅ Real Article URL: chrome-error://chromewebdata/
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#     - locator resolved to 109 elements. Proceeding with the first one: <a href="https://www.npr.org/series/pop-culture-happy-hour">…</a>
#   - attempting click action
#     2 × waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <div class="onetrust-pc-dark-filter ot-fade-in"></div> from <div id="onetrust-consent-sdk">…</div> subtree intercepts pointer events
#     - retrying click action
#     - waiting 20ms
#     2 × waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <div class="onetrust-pc-dark-filter ot-fade-in"></div> from <div id="onetrust-consent-sdk">…</div> subtree intercepts pointer events
#     - retrying click action
#       - waiting 100ms
#     8 × waiting for element to be visible, enabled and stable
#       - element is visible, enabled and stable
#       - scrolling into view if needed
#       - done scrolling
#       - <div class="onetrust-pc-dark-filter ot-fade-in"></div> from <div id="onetrust-consent-sdk">…</div> subtree intercepts pointer events
#     - retrying click action
#       - waiting 500ms
#
# 🔗 Resolved URL: https://www.npr.org/2025/05/15/nx-s1-5392026/eurovision-2025-best-songs
# ✅ Real Article URL: https://www.npr.org/2025/05/15/nx-s1-5392026/eurovision-2025-best-songs
# 🔗 Resolved URL: https://www.bbc.com/news/live/cvg7wp2jey6t
# ✅ Real Article URL: https://www.bbc.com/news/live/cvg7wp2jey6t
# 🔗 Resolved URL: https://wiwibloggs.com/category/news/eurovision-song-contest-2025/
# ✅ Real Article URL: https://wiwibloggs.com/category/news/eurovision-song-contest-2025/
# 🖱️ Click failed: Page.click: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("main a")
#
# 🔗 Resolved URL: https://eurovisionworld.com/esc/tonight-semi-final-1-of-the-eurovision-song-contest-2025
# ✅ Real Article URL: https://eurovisionworld.com/esc/tonight-semi-final-1-of-the-eurovision-song-contest-2025

# %%
import json
import re
import gc
import unicodedata
import requests
from bs4 import BeautifulSoup
import numpy as np
from sentence_transformers import SentenceTransformer


# Initialize model
model = SentenceTransformer('all-MiniLM-L6-v2')
 
# Constants
EVENTS_FILE_PATH = f'{event_path}/event.json'
OUTPUT_PATH = f'{event_path}/sentence_embeddings/'

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:120.0) Gecko/20100101 Firefox/120.0",
    "Accept-Language": "en-US,en;q=0.5",
    "Referer": "https://www.google.com/ ",
}


def load_events(file_path):
    """Load event data from JSON file."""
    try:
        logger.info(f"Loading events from {file_path}")
        with open(file_path, 'r') as f:
            return json.load(f)
    except Exception as e:
        logger.error(f"Error loading events from {file_path}: {e}")
        return []


def filter_url(url_info):
    """Filter URLs based on conditions."""
    url = url_info.get('real_url', '')
    if not url:
        return None

    try:
        conditions_met = (
            url.count('/') > 3 and
            len(re.findall(r'(author|topic|tag|category|youtube)', url)) < 1
        )
        return url_info if conditions_met else None
    except Exception as e:
        logger.warning(f"Error filtering URL {url}: {e}")
        return None


def normalize_unicode_text(text):
    """Normalize Unicode characters in text."""
    try:
        return unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    except Exception as e:
        logger.warning(f"Error normalizing Unicode text: {e}")
        return text


def clean_text(text):
    """Clean and preprocess raw HTML text content."""
    try:
        text = re.sub(r'\s+', ' ', text).strip()
        text = normalize_unicode_text(text)

        text = re.sub(r'https?://\S+|www\.\S+', '', text)  # Remove URLs
        text = re.sub(r'\S+@\S+', '', text)                # Remove emails
        text = re.sub(r'\d+', '', text)                    # Remove digits
        text = text.lower()

        return text
    except Exception as e:
        logger.warning(f"Error cleaning text: {e}")
        return ""


def extract_sentences(text):
    """Extract non-empty sentences from cleaned text."""
    try:
        sentences = clean_text(text).split('.')
        return [sentence.strip() for sentence in sentences if sentence.strip()]
    except Exception as e:
        logger.warning(f"Error extracting sentences: {e}")
        return []


def process_event_articles(event, articles_path):
    """Process all articles for a single event."""
    
    try:
        event_id = event['id']
        


        logger.info(f"Processing event ID: {event_id}")

        file_path = ARTICLES_PATH
        with open(file_path, 'r') as f:
            urls = json.load(f)

        filtered_urls = list(filter(None, [filter_url(url) for url in urls]))
        for url_info in filtered_urls:

            url = url_info.get('real_url', 'Unknown URL')
            article_id = url_info.get('id', 'Unknown ID')

            logger.info(f"Fetching URL: {url}")
            response = requests.get(url, headers=HEADERS)
            if response.status_code != 200:
                logger.warning(f"Failed to fetch {url} (Status {response.status_code})")
                continue

            soup = BeautifulSoup(response.content, 'html.parser')
            sentences = extract_sentences(soup.text)
            
            del soup, response
            gc.collect()

            if not sentences:
                logger.warning(f"No valid sentences extracted from {url}")
                continue

            embeddings = model.encode(sentences)
            output_path = f'{OUTPUT_PATH}{article_id}.npz'
            logger.info(f"Saving embeddings to {output_path}")

            with open(output_path, 'wb') as out_file:
                np.savez_compressed(out_file, embeddings)
            
            del sentences, embeddings
            gc.collect()
        

    except Exception as e:
        logger.error(f"Error processing event articles for ID {event_id}: {e}", exc_info=True)


event_id = event['id']

process_event_articles(event, ARTICLES_PATH)
# Out:
# Batches: 100%|██████████| 3/3 [00:05<00:00,  1.87s/it]
# Error processing event articles for ID 23935: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# Traceback (most recent call last):
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/connectionpool.py", line 773, in urlopen
#     self._prepare_proxy(conn)
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/connectionpool.py", line 1042, in _prepare_proxy
#     conn.connect()
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/connection.py", line 741, in connect
#     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/connection.py", line 920, in _ssl_wrap_socket_and_match_hostname
#     ssl_sock = ssl_wrap_socket(
#                ^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/util/ssl_.py", line 480, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/util/ssl_.py", line 524, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/ssl.py", line 517, in wrap_socket
#     return self.sslsocket_class._create(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/ssl.py", line 1104, in _create
#     self.do_handshake()
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/ssl.py", line 1382, in do_handshake
#     self._sslobj.do_handshake()
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/requests/adapters.py", line 667, in send
#     resp = conn.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/connectionpool.py", line 841, in urlopen
#     retries = retries.increment(
#               ^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/util/retry.py", line 474, in increment
#     raise reraise(type(error), error, _stacktrace)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/util/util.py", line 38, in reraise
#     raise value.with_traceback(tb)
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/connectionpool.py", line 773, in urlopen
#     self._prepare_proxy(conn)
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/connectionpool.py", line 1042, in _prepare_proxy
#     conn.connect()
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/connection.py", line 741, in connect
#     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/connection.py", line 920, in _ssl_wrap_socket_and_match_hostname
#     ssl_sock = ssl_wrap_socket(
#                ^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/util/ssl_.py", line 480, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/util/ssl_.py", line 524, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/ssl.py", line 517, in wrap_socket
#     return self.sslsocket_class._create(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/ssl.py", line 1104, in _create
#     self.do_handshake()
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/ssl.py", line 1382, in do_handshake
#     self._sslobj.do_handshake()
# urllib3.exceptions.ProtocolError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/1f/1t7knmh95bg_g1s30p6r8mp40000gn/T/ipykernel_99715/1407475341.py", line 110, in process_event_articles
#     response = requests.get(url, headers=HEADERS)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/requests/adapters.py", line 682, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# Error processing event articles for ID 23935: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# Traceback (most recent call last):
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/connectionpool.py", line 773, in urlopen
#     self._prepare_proxy(conn)
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/connectionpool.py", line 1042, in _prepare_proxy
#     conn.connect()
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/connection.py", line 741, in connect
#     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/connection.py", line 920, in _ssl_wrap_socket_and_match_hostname
#     ssl_sock = ssl_wrap_socket(
#                ^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/util/ssl_.py", line 480, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/util/ssl_.py", line 524, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/ssl.py", line 517, in wrap_socket
#     return self.sslsocket_class._create(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/ssl.py", line 1104, in _create
#     self.do_handshake()
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/ssl.py", line 1382, in do_handshake
#     self._sslobj.do_handshake()
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/requests/adapters.py", line 667, in send
#     resp = conn.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/connectionpool.py", line 841, in urlopen
#     retries = retries.increment(
#               ^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/util/retry.py", line 474, in increment
#     raise reraise(type(error), error, _stacktrace)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/util/util.py", line 38, in reraise
#     raise value.with_traceback(tb)
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/connectionpool.py", line 773, in urlopen
#     self._prepare_proxy(conn)
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/connectionpool.py", line 1042, in _prepare_proxy
#     conn.connect()
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/connection.py", line 741, in connect
#     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/connection.py", line 920, in _ssl_wrap_socket_and_match_hostname
#     ssl_sock = ssl_wrap_socket(
#                ^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/util/ssl_.py", line 480, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/urllib3/util/ssl_.py", line 524, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/ssl.py", line 517, in wrap_socket
#     return self.sslsocket_class._create(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/ssl.py", line 1104, in _create
#     self.do_handshake()
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/ssl.py", line 1382, in do_handshake
#     self._sslobj.do_handshake()
# urllib3.exceptions.ProtocolError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/1f/1t7knmh95bg_g1s30p6r8mp40000gn/T/ipykernel_99715/1407475341.py", line 110, in process_event_articles
#     response = requests.get(url, headers=HEADERS)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ivanesipov/miniconda/envs/diploma_env/lib/python3.11/site-packages/requests/adapters.py", line 682, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))

# %%
import os
import json
import logging
import numpy as np
from tqdm import tqdm
from itertools import combinations
import networkx as nx
from transformers import BertTokenizer, BertForTokenClassification, pipeline

# Local imports
import sys
sys.path.insert(0, '..')
from utils.base import load_events  # Assuming this wraps `json.load`

# --- Paths ---

EVENTS_PATH = f'{event_path}/event.json'
EMBEDDINGS_PATH = f'{event_path}/sentence_embeddings/'
ARTICLES_PATH = f'{event_path}/articles.json'
GRAPH_PATH = f'{event_path}/graph.graphml'

SHARE_THRESHOLD = 0.35

# --- NER Setup ---
try:
    tokenizer = BertTokenizer.from_pretrained("bert-base-cased")
    model = BertForTokenClassification.from_pretrained("dslim/bert-base-NER")
    ner_pipeline = pipeline("ner", model=model, tokenizer=tokenizer)
    logger.info("NER pipeline loaded successfully.")
except Exception as e:
    logger.error(f"Failed to load NER pipeline: {e}")
    raise


def extract_entities(title):
    """Extract unique named entities from a title using the NER pipeline."""
    try:
        ner_results = ner_pipeline(title)
        return set(entity['word'] for entity in ner_results if entity['entity'].startswith('B-'))
    except Exception as e:
        logger.warning(f"Error extracting entities from title: {e}")
        return set()


def stream_articles(file_path):
    """Stream articles from a JSON file one by one to reduce memory usage."""
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            articles = json.load(f)
            for article in articles:
                yield article
    except FileNotFoundError:
        logger.warning(f"File not found: {file_path}")
    except json.JSONDecodeError as e:
        logger.warning(f"JSON decode error in {file_path}: {e}")


def build_event_graph(event, articles_file_path):
    """Build a NetworkX graph based on article relationships for a single event."""
    logger.info(f"Building graph for event")

    # Get embedded article IDs related to this event
    try:
        embedded_article_ids = [x.split('.')[0] for x in os.listdir(EMBEDDINGS_PATH)]
        logger.debug(f"Found {len(embedded_article_ids)} embedded article IDs for event")
    except Exception as e:
        logger.error(f"Error reading embeddings directory for event: {e}")
        return None

    valid_articles = []
    for article in stream_articles(articles_file_path):
        aid = article.get('id')
        if aid in embedded_article_ids:
            try:
                article['ner'] = extract_entities(article['title'])
                valid_articles.append(article)
            except Exception as e:
                logger.warning(f"Error processing article {aid}: {e}")

    if not valid_articles:
        logger.warning(f"No valid articles found for event")
        return None

    logger.info(f"Processing {len(valid_articles)} valid articles for event")

    # Build graph
    G = nx.Graph()

    # Add nodes
    for item in valid_articles:
        G.add_node(item['id'], article=item['real_url'])

    # Add edges
    for a, b in combinations(valid_articles, 2):
        id_a, id_b = a['id'], b['id']
        same_date = a['date'] == b['date']
        same_query = a['query'] == b['query']
        same_publisher = a['publisher'] == b['publisher']

        common_entities = a['ner'].intersection(b['ner'])
        common_entities_share = len(common_entities) / max(len(a['ner']) or 1, len(b['ner']) or 1)

        if any([same_date, same_query, same_publisher, common_entities_share > SHARE_THRESHOLD]):
            G.add_edge(
                id_a,
                id_b,
                same_date=same_date,
                same_query=same_query,
                same_publisher=same_publisher,
                common_entities_share=common_entities_share,
            )

    logger.info(f"Built graph with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges for event")
    return G


def main():
    try:
        events = load_events(EVENTS_PATH)
        logger.info(f"Loaded {len(events)} events from {EVENTS_PATH}")
    except Exception as e:
        logger.error(f"Failed to load events from {EVENTS_PATH}: {e}")
        return


    for i, event in enumerate(events):

        articles_file = ARTICLES_PATH

        if not os.path.exists(articles_file):
            logger.warning(f"Articles file does not exist: {articles_file}")
            continue

        logger.info(f"Starting graph construction for e")
        G = build_event_graph(event, articles_file)

        if G is not None:
            output_file = GRAPH_PATH
            nx.write_graphml(G, output_file)
            logger.info(f"Saved graph for e to {output_file}")
        else:
            logger.warning(f"Graph for e was not saved (None returned)")


if __name__ == '__main__':
    main()
# Out:
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use mps:0

# %%
# TRAINING_GRAPH_PATH = f'{event_path}/training_graph.pickle'
# TRAINING_GRAPH_PATH

# %%
# Inference p.1
import os
import json
import torch
import joblib
import networkx as nx
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm
from datetime import datetime
from sentence_transformers import SentenceTransformer
from torch_geometric.loader import DataLoader
from torch_geometric.data import Data
from torch_geometric.utils import dropout
from torch_geometric.utils.convert import from_networkx
import sys

# Project root and path setup
sys.path.insert(0, ROOT)
TRAINING_GRAPH_PATH = f'{event_path}/training_graph.pickle'

def get_similarity_vector(article_emb, question_emb, model):
    """Calculate similarity vector between article and question embeddings."""
    similarities_list = [
        model.similarity(s_emb, question_emb) 
        for s_emb in article_emb['arr_0']
    ]
    
    n = 10
    similarities = torch.cat(similarities_list)
    idx = similarities.argsort(dim=0, descending=True)[:n]
    
    article_similarity = torch.cat([
        torch.quantile(similarities, torch.tensor([i/10.0 for i in range(10)]), 
                      dim=0, keepdim=False).flatten(),
        torch.tensor([similarities.mean(), max(0, similarities[idx].std()), len(similarities > 0.5)]),
    ])
    
    return article_similarity

def clear_attrs(graph):
    """Remove specified attributes from graph."""
    keys = [
        'same_date',
        'common_entities_share',
        'same_query',
        'same_publisher'
    ]
    
    for key in keys:
        del graph[key]
    
    return graph

def generate_graph(market, G, model):
    """Generate graph with node embeddings and labels."""
    # Label
    pos = np.argmax(eval(market['outcomePrices']))
    y = np.where(eval(market['outcomes'])[pos] == 'No', 0, 1)
    
    # Question embedding
    market_question = market['question']
    question_emb = model.encode(market_question)
    
    for node_id in G.nodes:
        article_emb = np.load(f'{EMBEDDINGS_PATH}{node_id}.npz')
        node_vector = get_similarity_vector(article_emb, question_emb, model=model)
        G.nodes[node_id]['embedding'] = node_vector
    
    graph = from_networkx(G)
    graph.y = torch.tensor(y)
    
    return graph

def add_key(graph_list, key):
    """Add specified key to graphs if missing."""
    key = 'same_date'
    for g in graph_list:
        try:
            g[key]
        except KeyError:
            g[key] = torch.zeros(g.edge_index.size()[1])
    
    graph_list_new = [
        Data(
            x=g['embedding'],
            y=g['y'],
            edge_index=g['edge_index'],
            same_date=g[key]
        ) 
        for g in graph_list if g is not None
    ]
    return graph_list_new

# Initialize sentence transformer
sentence_transformer = SentenceTransformer("all-MiniLM-L6-v2")

# Process all events

graphs = []

G = nx.read_graphml(GRAPH_PATH)
for market in event['markets']:
    try:
        graphs.append(
            generate_graph(market, G=G, model=sentence_transformer)
        )
    except Exception as e:
        print(f"Error processing market: {e}")
        
graph_data = add_key(graphs, 'same_date')

with open(TRAINING_GRAPH_PATH, 'wb') as f:
    joblib.dump(graph_data, f)
# Out:
# Batches: 100%|██████████| 1/1 [00:00<00:00,  1.01it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.44it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.85it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 25.12it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 25.78it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 25.40it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 25.64it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 25.87it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 25.62it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 25.72it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  2.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.86it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.92it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 25.99it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 25.84it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 25.54it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 25.52it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 25.91it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 26.18it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 26.25it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 25.94it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 25.67it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 25.26it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.90it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 25.51it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.93it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 25.92it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 26.09it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 26.42it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 26.18it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 26.25it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 26.06it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 26.53it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 25.65it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 26.16it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 26.29it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 26.14it/s]

# %%
with open(TRAINING_GRAPH_PATH, 'rb') as f:
    graph_data = joblib.load(f)

# %%
# Inference p.2

import torch
import sys
sys.path.insert(0, '..')
from utils.models.gcn_v1 import GCNGraphClassifier_v1
from utils.models.gcn_v2 import GCNGraphClassifier_v2
from utils.models.baseline import BaselineClassifier


dataloader = DataLoader(graph_data, batch_size=1)

model = GCNGraphClassifier_v2(13, 64)
state_dict = torch.load('../models/GCNGraphClassifier_v2_20250517_164339.pth')
model.load_state_dict(state_dict)

model.eval()
out_list, predictions = [], []
for data in dataloader:
    out = model(data)
    pred = out.max(1)[1]
    predictions.append(pred)
    out_list.append(out)

# %%
# torch.cat(out_list).max(0)
torch.cat(out_list).argsort(0)[:, 1]
# Out:
# tensor([34, 10,  4, 36, 13,  1, 35, 32, 15,  9, 26,  0, 22, 11,  8,  7, 25,  6,
#         33, 18, 29, 19, 21, 23,  5,  2, 20, 17, 14, 24, 31, 16, 30, 12, 27, 28,
#          3])

# %%
from tsfresh import extract_features
import pandas as pd


with open('../models/price_predictor.pkl', 'rb') as f:
    price_clf = joblib.load(f)


def series_to_tsfresh_df(history, series_id):
    return pd.DataFrame({
        'id': [series_id for _ in history],
        'time': [point['t'] for point in history],
        'value': [point['p'] for point in history]
    })

X = series_to_tsfresh_df(event['markets'][4]['prices_history'][0]['history'], series_id=4)
X = extract_features(X, column_id='id', column_sort='time', column_value='value')

prediction = price_clf.predict_proba(X)
prediction
# Out:
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Feature Extraction: 100%|██████████| 1/1 [00:03<00:00,  3.20s/it]
# array([[0.27728431, 0.72271569]])

# %%
graph_preds = torch.exp(torch.cat(out_list))[:,0]
for i, m in enumerate(event['markets']):
    graph_pred = graph_preds[i]
    try:
        X = series_to_tsfresh_df(m['prices_history'][0]['history'], series_id=0)
        X = extract_features(X, column_id='id', column_sort='time', column_value='value')
        X.replace([np.inf, -np.inf], np.nan, inplace=True)

        price_pred = price_clf.predict_proba(X)[:, 1].item()

        print(f"Market {m['question']}, Graph Prediction: {graph_pred:.4f}, Price Prediction: {price_pred:.4f}")
    except:
        continue
# Out:
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Feature Extraction: 100%|██████████| 1/1 [00:04<00:00,  4.34s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Sweden finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3284, Price Prediction: 0.8868
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.55s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Austria finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3301, Price Prediction: 0.8409
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.66s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will France finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3251, Price Prediction: 0.9520
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.38s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Israel finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3192, Price Prediction: 0.7710
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.36s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Netherlands finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3318, Price Prediction: 0.7227
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.55s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Finland finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3252, Price Prediction: 0.6990
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.44s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Estonia finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3268, Price Prediction: 0.5716
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.36s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Ukraine finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3272, Price Prediction: 0.1267
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.45s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Albania finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3275, Price Prediction: 0.5663
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.33s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Belgium finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3291, Price Prediction: 0.2004
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.40s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Czechia finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3322, Price Prediction: 0.1267
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.37s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Italy finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3279, Price Prediction: 0.2457
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.74s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will San Marino finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3223, Price Prediction: 0.3517
# Feature Extraction: 100%|██████████| 1/1 [00:03<00:00,  3.49s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Germany finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3304, Price Prediction: 0.2982
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.81s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Malta finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3241, Price Prediction: 0.3434
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.63s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will United Kingdom finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3295, Price Prediction: 0.2131
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.85s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Norway finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3233, Price Prediction: 0.3405
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.93s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Switzerland finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3244, Price Prediction: 0.4451
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.82s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Australia finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3265, Price Prediction: 0.2342
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.88s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Greece finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3257, Price Prediction: 0.2338
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.71s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Spain finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3250, Price Prediction: 0.4154
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.54s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Ireland finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3257, Price Prediction: 0.1842
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.64s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Poland finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3281, Price Prediction: 0.3154
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.85s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Cyprus finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3253, Price Prediction: 0.2671
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.94s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Lithuania finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3239, Price Prediction: 0.3214
# Feature Extraction: 100%|██████████| 1/1 [00:03<00:00,  3.07s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Luxembourg finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3268, Price Prediction: 0.2987
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.76s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Latvia finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3290, Price Prediction: 0.4302
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.68s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Georgia finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3221, Price Prediction: 0.2938
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.53s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Azerbaijan finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3216, Price Prediction: 0.1802
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.80s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Portugal finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3262, Price Prediction: 0.3260
# Feature Extraction: 100%|██████████| 1/1 [00:03<00:00,  3.11s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Iceland finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3226, Price Prediction: 0.3239
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  3.00s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Armenia finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3236, Price Prediction: 0.3826
# Feature Extraction: 100%|██████████| 1/1 [00:03<00:00,  3.03s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Serbia finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3297, Price Prediction: 0.3438
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.73s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Denmark finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3268, Price Prediction: 0.3517
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.45s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Slovenia finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3340, Price Prediction: 0.1307
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.68s/it]
# Dependency not available for matrix_profile, this feature will be disabled!
# Dependency not available for matrix_profile, this feature will be disabled!
# Market Will Montenegro finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3299, Price Prediction: 0.4570
# Feature Extraction: 100%|██████████| 1/1 [00:02<00:00,  2.77s/it]
# Market Will Croatia finish in the 2025 Eurovision top 5?, Graph Prediction: 0.3318, Price Prediction: 0.2478

# %%
m
# Out:
# {'id': '541504',
#  'question': 'Will Croatia finish in the 2025 Eurovision top 5?',
#  'conditionId': '0x6988235ff80eb52d22a93d5110d5a9012dffa662ec512765ed1771cdd846f0b8',
#  'slug': 'will-croatia-finish-in-the-2025-eurovision-top-5',
#  'resolutionSource': '',
#  'endDate': '2025-05-17T12:00:00Z',
#  'startDate': '2025-05-05T20:28:43.839822Z',
#  'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/flag+croatia.png',
#  'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/flag+croatia.png',
#  'description': 'This market will resolve to "Yes" if the named country finishes Eurovision 2025 as one of the top 5 highest scoring candidates.\n\nIf at any point it is impossible for the listed candidate to finish as one of the top 5 highest scorers based on the rules of the competition (i.e. they are eliminated), this market may immediately resolve to "No".\n\nIf no winner is announced by July 31, 2025, 11:59 PM ET, this market will resolve to "No".\n\nThe primary resolution source for this market will be official information from Eurovision (https://eurovision.tv/), including live footage of Eurovision 2025, however a consensus of credible reporting will suffice.',
#  'outcomes': '["Yes", "No"]',
#  'outcomePrices': '["0", "1"]',
#  'volume': '8695.977863',
#  'active': True,
#  'closed': True,
#  'marketMakerAddress': '',
#  'createdAt': '2025-05-05T18:52:26.046346Z',
#  'updatedAt': '2025-05-15T00:23:13.502958Z',
#  'closedTime': '2025-05-14 01:20:50+00',
#  'new': False,
#  'featured': False,
#  'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5',
#  'archived': False,
#  'resolvedBy': '0x6A9D222616C90FcA5754cd1333cFD9b7fb6a4F74',
#  'restricted': True,
#  'groupItemTitle': 'Croatia',
#  'groupItemThreshold': '36',
#  'questionID': '0xb2eae47cc34f43e2dcc8cf446b94397e1252f17a0bbe22be06bdbb52ed715958',
#  'umaEndDate': '2025-05-14T01:20:50Z',
#  'enableOrderBook': True,
#  'orderPriceMinTickSize': 0.001,
#  'orderMinSize': 5,
#  'umaResolutionStatus': 'resolved',
#  'volumeNum': 8695.977863,
#  'endDateIso': '2025-05-17',
#  'startDateIso': '2025-05-05',
#  'hasReviewedDates': True,
#  'volume1wk': 8565.977863,
#  'volume1mo': 8695.977863,
#  'volume1yr': 8695.977863,
#  'clobTokenIds': '["113047129851018554210524655525568259611218765867144179866087788519241860917490", "80863511564245649743807429494891385861523126693994569384033020107850617685394"]',
#  'umaBond': '500',
#  'umaReward': '5',
#  'volume1wkClob': 8565.977863,
#  'volume1moClob': 8695.977863,
#  'volume1yrClob': 8695.977863,
#  'volumeClob': 8695.977863,
#  'acceptingOrders': False,
#  'negRisk': False,
#  'negRiskRequestID': '',
#  'ready': False,
#  'funded': False,
#  'acceptingOrdersTimestamp': '2025-05-05T20:28:13Z',
#  'cyom': False,
#  'pagerDutyNotificationEnabled': False,
#  'approved': True,
#  'clobRewards': [{'id': '22902',
#    'conditionId': '0x6988235ff80eb52d22a93d5110d5a9012dffa662ec512765ed1771cdd846f0b8',
#    'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174',
#    'rewardsAmount': 0,
#    'rewardsDailyRate': 2,
#    'startDate': '2025-05-05',
#    'endDate': '2500-12-31'}],
#  'rewardsMinSize': 50,
#  'rewardsMaxSpread': 3.5,
#  'spread': 0.001,
#  'automaticallyResolved': True,
#  'oneDayPriceChange': -0.0075,
#  'oneWeekPriceChange': -0.0105,
#  'lastTradePrice': 1,
#  'bestAsk': 0.001,
#  'automaticallyActive': True,
#  'clearBookOnStart': True,
#  'seriesColor': '',
#  'showGmpSeries': False,
#  'showGmpOutcome': False,
#  'manualActivation': False,
#  'negRiskOther': False,
#  'umaResolutionStatuses': '["proposed"]',
#  'pendingDeployment': False,
#  'deploying': False,
#  'deployingTimestamp': '2025-05-05T20:27:11.884856Z',
#  'prices_history': [{'history': [{'t': 1746478805, 'p': 0.0255},
#     {'t': 1746482406, 'p': 0.01},
#     {'t': 1746486005, 'p': 0.01},
#     {'t': 1746489606, 'p': 0.014},
#     {'t': 1746493205, 'p': 0.01},
#     {'t': 1746496805, 'p': 0.01},
#     {'t': 1746500405, 'p': 0.011},
#     {'t': 1746504005, 'p': 0.0105},
#     {'t': 1746507606, 'p': 0.0105},
#     {'t': 1746511205, 'p': 0.011},
#     {'t': 1746514805, 'p': 0.01},
#     {'t': 1746518405, 'p': 0.0105},
#     {'t': 1746522005, 'p': 0.011},
#     {'t': 1746525605, 'p': 0.011},
#     {'t': 1746529206, 'p': 0.0105},
#     {'t': 1746532805, 'p': 0.0095},
#     {'t': 1746536405, 'p': 0.0105},
#     {'t': 1746540006, 'p': 0.0095},
#     {'t': 1746543605, 'p': 0.0095},
#     {'t': 1746547206, 'p': 0.0105},
#     {'t': 1746550805, 'p': 0.011},
#     {'t': 1746554406, 'p': 0.011},
#     {'t': 1746558006, 'p': 0.011},
#     {'t': 1746561606, 'p': 0.011},
#     {'t': 1746565205, 'p': 0.0105},
#     {'t': 1746568806, 'p': 0.0105},
#     {'t': 1746572406, 'p': 0.0105},
#     {'t': 1746576005, 'p': 0.011},
#     {'t': 1746579606, 'p': 0.0105},
#     {'t': 1746583206, 'p': 0.0105},
#     {'t': 1746586806, 'p': 0.0105},
#     {'t': 1746590406, 'p': 0.0105},
#     {'t': 1746594006, 'p': 0.0105},
#     {'t': 1746597606, 'p': 0.0105},
#     {'t': 1746601206, 'p': 0.0105},
#     {'t': 1746604806, 'p': 0.0105},
#     {'t': 1746608406, 'p': 0.0105},
#     {'t': 1746612006, 'p': 0.0105},
#     {'t': 1746615606, 'p': 0.0105},
#     {'t': 1746619206, 'p': 0.0115},
#     {'t': 1746622806, 'p': 0.0105},
#     {'t': 1746626406, 'p': 0.0105},
#     {'t': 1746630006, 'p': 0.0105},
#     {'t': 1746633606, 'p': 0.0105},
#     {'t': 1746637207, 'p': 0.0105},
#     {'t': 1746640806, 'p': 0.0105},
#     {'t': 1746644406, 'p': 0.0105},
#     {'t': 1746648006, 'p': 0.0105},
#     {'t': 1746651606, 'p': 0.0105},
#     {'t': 1746655206, 'p': 0.0105},
#     {'t': 1746658806, 'p': 0.011},
#     {'t': 1746662406, 'p': 0.0105},
#     {'t': 1746666006, 'p': 0.01},
#     {'t': 1746669606, 'p': 0.01},
#     {'t': 1746673206, 'p': 0.0105},
#     {'t': 1746676806, 'p': 0.01},
#     {'t': 1746680406, 'p': 0.01},
#     {'t': 1746684006, 'p': 0.01},
#     {'t': 1746687606, 'p': 0.01},
#     {'t': 1746691206, 'p': 0.01},
#     {'t': 1746694806, 'p': 0.01},
#     {'t': 1746698406, 'p': 0.01},
#     {'t': 1746702005, 'p': 0.01},
#     {'t': 1746705606, 'p': 0.01},
#     {'t': 1746709206, 'p': 0.01},
#     {'t': 1746712806, 'p': 0.0085},
#     {'t': 1746716406, 'p': 0.0085},
#     {'t': 1746720006, 'p': 0.0105},
#     {'t': 1746723606, 'p': 0.0105},
#     {'t': 1746727206, 'p': 0.0105},
#     {'t': 1746730806, 'p': 0.01},
#     {'t': 1746734406, 'p': 0.01},
#     {'t': 1746738006, 'p': 0.01},
#     {'t': 1746741606, 'p': 0.01},
#     {'t': 1746745206, 'p': 0.01},
#     {'t': 1746748807, 'p': 0.01},
#     {'t': 1746752407, 'p': 0.0105},
#     {'t': 1746756006, 'p': 0.0105},
#     {'t': 1746759607, 'p': 0.01},
#     {'t': 1746763206, 'p': 0.01},
#     {'t': 1746766806, 'p': 0.01},
#     {'t': 1746770406, 'p': 0.0105},
#     {'t': 1746774006, 'p': 0.01},
#     {'t': 1746777607, 'p': 0.01},
#     {'t': 1746781206, 'p': 0.0105},
#     {'t': 1746784806, 'p': 0.0105},
#     {'t': 1746788406, 'p': 0.0105},
#     {'t': 1746792007, 'p': 0.0105},
#     {'t': 1746795607, 'p': 0.0105},
#     {'t': 1746799206, 'p': 0.011},
#     {'t': 1746802807, 'p': 0.0105},
#     {'t': 1746806407, 'p': 0.0105},
#     {'t': 1746810007, 'p': 0.0105},
#     {'t': 1746813607, 'p': 0.0105},
#     {'t': 1746817207, 'p': 0.0105},
#     {'t': 1746820806, 'p': 0.0105},
#     {'t': 1746824406, 'p': 0.0105},
#     {'t': 1746828007, 'p': 0.0105},
#     {'t': 1746831606, 'p': 0.0105},
#     {'t': 1746835206, 'p': 0.011},
#     {'t': 1746838806, 'p': 0.0105},
#     {'t': 1746842406, 'p': 0.0105},
#     {'t': 1746846006, 'p': 0.0105},
#     {'t': 1746849606, 'p': 0.0105},
#     {'t': 1746853206, 'p': 0.011},
#     {'t': 1746856806, 'p': 0.0105},
#     {'t': 1746860406, 'p': 0.0105},
#     {'t': 1746864007, 'p': 0.0105},
#     {'t': 1746867605, 'p': 0.0105},
#     {'t': 1746871206, 'p': 0.0105},
#     {'t': 1746874806, 'p': 0.0105},
#     {'t': 1746878406, 'p': 0.011},
#     {'t': 1746882006, 'p': 0.011},
#     {'t': 1746885606, 'p': 0.011},
#     {'t': 1746889206, 'p': 0.011},
#     {'t': 1746892807, 'p': 0.0105},
#     {'t': 1746896407, 'p': 0.0105},
#     {'t': 1746900007, 'p': 0.0105},
#     {'t': 1746903606, 'p': 0.0105},
#     {'t': 1746907206, 'p': 0.0105},
#     {'t': 1746910806, 'p': 0.0105},
#     {'t': 1746914406, 'p': 0.0105},
#     {'t': 1746918006, 'p': 0.0115},
#     {'t': 1746921606, 'p': 0.016},
#     {'t': 1746925206, 'p': 0.0155},
#     {'t': 1746928806, 'p': 0.0155},
#     {'t': 1746932406, 'p': 0.0155},
#     {'t': 1746936006, 'p': 0.0155},
#     {'t': 1746939606, 'p': 0.0155},
#     {'t': 1746943206, 'p': 0.016},
#     {'t': 1746946807, 'p': 0.016},
#     {'t': 1746950406, 'p': 0.016},
#     {'t': 1746954007, 'p': 0.0155},
#     {'t': 1746957607, 'p': 0.0155},
#     {'t': 1746961207, 'p': 0.0155},
#     {'t': 1746964807, 'p': 0.0155},
#     {'t': 1746968406, 'p': 0.016},
#     {'t': 1746972007, 'p': 0.0185},
#     {'t': 1746975606, 'p': 0.018},
#     {'t': 1746979207, 'p': 0.0185},
#     {'t': 1746982806, 'p': 0.018},
#     {'t': 1746986407, 'p': 0.0175},
#     {'t': 1746990007, 'p': 0.0175},
#     {'t': 1746993607, 'p': 0.0175},
#     {'t': 1746997206, 'p': 0.018},
#     {'t': 1747000806, 'p': 0.0185},
#     {'t': 1747004406, 'p': 0.021},
#     {'t': 1747008006, 'p': 0.0185},
#     {'t': 1747011606, 'p': 0.019},
#     {'t': 1747015206, 'p': 0.0175},
#     {'t': 1747018806, 'p': 0.0165},
#     {'t': 1747022406, 'p': 0.016},
#     {'t': 1747026006, 'p': 0.016},
#     {'t': 1747029607, 'p': 0.017},
#     {'t': 1747033206, 'p': 0.016},
#     {'t': 1747036806, 'p': 0.015},
#     {'t': 1747040406, 'p': 0.015},
#     {'t': 1747044006, 'p': 0.015},
#     {'t': 1747047607, 'p': 0.015},
#     {'t': 1747051206, 'p': 0.0155},
#     {'t': 1747054806, 'p': 0.016},
#     {'t': 1747058406, 'p': 0.016},
#     {'t': 1747062007, 'p': 0.015},
#     {'t': 1747065606, 'p': 0.015},
#     {'t': 1747069206, 'p': 0.015},
#     {'t': 1747072805, 'p': 0.015},
#     {'t': 1747076406, 'p': 0.015},
#     {'t': 1747080007, 'p': 0.015},
#     {'t': 1747083607, 'p': 0.009},
#     {'t': 1747087205, 'p': 0.01},
#     {'t': 1747090806, 'p': 0.01},
#     {'t': 1747094406, 'p': 0.008},
#     {'t': 1747098007, 'p': 0.0095},
#     {'t': 1747101606, 'p': 0.0075},
#     {'t': 1747105207, 'p': 0.01},
#     {'t': 1747108806, 'p': 0.0085},
#     {'t': 1747112407, 'p': 0.0085},
#     {'t': 1747116007, 'p': 0.0095},
#     {'t': 1747119607, 'p': 0.0055},
#     {'t': 1747123206, 'p': 0.0055},
#     {'t': 1747126807, 'p': 0.0055},
#     {'t': 1747130406, 'p': 0.0055},
#     {'t': 1747134007, 'p': 0.0055},
#     {'t': 1747137607, 'p': 0.0055},
#     {'t': 1747141207, 'p': 0.0055},
#     {'t': 1747144806, 'p': 0.0055},
#     {'t': 1747148406, 'p': 0.0055},
#     {'t': 1747152007, 'p': 0.008},
#     {'t': 1747155607, 'p': 0.006},
#     {'t': 1747159207, 'p': 0.0065},
#     {'t': 1747162806, 'p': 0.006},
#     {'t': 1747166407, 'p': 0.011},
#     {'t': 1747170007, 'p': 0.0075},
#     {'t': 1747173607, 'p': 0.0005},
#     {'t': 1747177207, 'p': 0.0005},
#     {'t': 1747180807, 'p': 0.0005},
#     {'t': 1747184407, 'p': 0.0005}]},
#   {'history': [{'t': 1746478805, 'p': 0.9745},
#     {'t': 1746482406, 'p': 0.99},
#     {'t': 1746486005, 'p': 0.99},
#     {'t': 1746489606, 'p': 0.986},
#     {'t': 1746493205, 'p': 0.99},
#     {'t': 1746496805, 'p': 0.99},
#     {'t': 1746500405, 'p': 0.989},
#     {'t': 1746504005, 'p': 0.9895},
#     {'t': 1746507606, 'p': 0.9895},
#     {'t': 1746511205, 'p': 0.989},
#     {'t': 1746514805, 'p': 0.99},
#     {'t': 1746518405, 'p': 0.9895},
#     {'t': 1746522005, 'p': 0.989},
#     {'t': 1746525605, 'p': 0.989},
#     {'t': 1746529206, 'p': 0.9895},
#     {'t': 1746532805, 'p': 0.9905},
#     {'t': 1746536405, 'p': 0.9895},
#     {'t': 1746540006, 'p': 0.9905},
#     {'t': 1746543605, 'p': 0.9905},
#     {'t': 1746547206, 'p': 0.9895},
#     {'t': 1746550805, 'p': 0.989},
#     {'t': 1746554406, 'p': 0.989},
#     {'t': 1746558006, 'p': 0.989},
#     {'t': 1746561606, 'p': 0.989},
#     {'t': 1746565205, 'p': 0.9895},
#     {'t': 1746568806, 'p': 0.9895},
#     {'t': 1746572406, 'p': 0.9895},
#     {'t': 1746576005, 'p': 0.989},
#     {'t': 1746579606, 'p': 0.9895},
#     {'t': 1746583206, 'p': 0.9895},
#     {'t': 1746586806, 'p': 0.9895},
#     {'t': 1746590406, 'p': 0.9895},
#     {'t': 1746594006, 'p': 0.9895},
#     {'t': 1746597606, 'p': 0.9895},
#     {'t': 1746601206, 'p': 0.9895},
#     {'t': 1746604806, 'p': 0.9895},
#     {'t': 1746608406, 'p': 0.9895},
#     {'t': 1746612006, 'p': 0.9895},
#     {'t': 1746615606, 'p': 0.9895},
#     {'t': 1746619206, 'p': 0.9885},
#     {'t': 1746622806, 'p': 0.9895},
#     {'t': 1746626406, 'p': 0.9895},
#     {'t': 1746630006, 'p': 0.9895},
#     {'t': 1746633606, 'p': 0.9895},
#     {'t': 1746637207, 'p': 0.9895},
#     {'t': 1746640806, 'p': 0.9895},
#     {'t': 1746644406, 'p': 0.9895},
#     {'t': 1746648006, 'p': 0.9895},
#     {'t': 1746651606, 'p': 0.9895},
#     {'t': 1746655206, 'p': 0.9895},
#     {'t': 1746658806, 'p': 0.989},
#     {'t': 1746662406, 'p': 0.9895},
#     {'t': 1746666006, 'p': 0.99},
#     {'t': 1746669606, 'p': 0.99},
#     {'t': 1746673206, 'p': 0.9895},
#     {'t': 1746676806, 'p': 0.99},
#     {'t': 1746680406, 'p': 0.99},
#     {'t': 1746684006, 'p': 0.99},
#     {'t': 1746687606, 'p': 0.99},
#     {'t': 1746691206, 'p': 0.99},
#     {'t': 1746694806, 'p': 0.99},
#     {'t': 1746698406, 'p': 0.99},
#     {'t': 1746702005, 'p': 0.99},
#     {'t': 1746705606, 'p': 0.99},
#     {'t': 1746709206, 'p': 0.99},
#     {'t': 1746712806, 'p': 0.9915},
#     {'t': 1746716406, 'p': 0.9915},
#     {'t': 1746720006, 'p': 0.9895},
#     {'t': 1746723606, 'p': 0.9895},
#     {'t': 1746727206, 'p': 0.9895},
#     {'t': 1746730806, 'p': 0.99},
#     {'t': 1746734406, 'p': 0.99},
#     {'t': 1746738006, 'p': 0.99},
#     {'t': 1746741606, 'p': 0.99},
#     {'t': 1746745206, 'p': 0.99},
#     {'t': 1746748807, 'p': 0.99},
#     {'t': 1746752407, 'p': 0.9895},
#     {'t': 1746756006, 'p': 0.9895},
#     {'t': 1746759607, 'p': 0.99},
#     {'t': 1746763206, 'p': 0.99},
#     {'t': 1746766806, 'p': 0.99},
#     {'t': 1746770406, 'p': 0.9895},
#     {'t': 1746774006, 'p': 0.99},
#     {'t': 1746777607, 'p': 0.99},
#     {'t': 1746781206, 'p': 0.9895},
#     {'t': 1746784806, 'p': 0.9895},
#     {'t': 1746788406, 'p': 0.9895},
#     {'t': 1746792007, 'p': 0.9895},
#     {'t': 1746795607, 'p': 0.9895},
#     {'t': 1746799206, 'p': 0.989},
#     {'t': 1746802807, 'p': 0.9895},
#     {'t': 1746806407, 'p': 0.9895},
#     {'t': 1746810007, 'p': 0.9895},
#     {'t': 1746813607, 'p': 0.9895},
#     {'t': 1746817207, 'p': 0.9895},
#     {'t': 1746820806, 'p': 0.9895},
#     {'t': 1746824406, 'p': 0.9895},
#     {'t': 1746828007, 'p': 0.9895},
#     {'t': 1746831606, 'p': 0.9895},
#     {'t': 1746835206, 'p': 0.989},
#     {'t': 1746838806, 'p': 0.9895},
#     {'t': 1746842406, 'p': 0.9895},
#     {'t': 1746846006, 'p': 0.9895},
#     {'t': 1746849606, 'p': 0.9895},
#     {'t': 1746853206, 'p': 0.989},
#     {'t': 1746856806, 'p': 0.9895},
#     {'t': 1746860406, 'p': 0.9895},
#     {'t': 1746864007, 'p': 0.9895},
#     {'t': 1746867605, 'p': 0.9895},
#     {'t': 1746871206, 'p': 0.9895},
#     {'t': 1746874806, 'p': 0.9895},
#     {'t': 1746878406, 'p': 0.989},
#     {'t': 1746882006, 'p': 0.989},
#     {'t': 1746885606, 'p': 0.989},
#     {'t': 1746889206, 'p': 0.989},
#     {'t': 1746892807, 'p': 0.9895},
#     {'t': 1746896407, 'p': 0.9895},
#     {'t': 1746900007, 'p': 0.9895},
#     {'t': 1746903606, 'p': 0.9895},
#     {'t': 1746907206, 'p': 0.9895},
#     {'t': 1746910806, 'p': 0.9895},
#     {'t': 1746914406, 'p': 0.9895},
#     {'t': 1746918006, 'p': 0.9885},
#     {'t': 1746921606, 'p': 0.984},
#     {'t': 1746925206, 'p': 0.9845},
#     {'t': 1746928806, 'p': 0.9845},
#     {'t': 1746932406, 'p': 0.9845},
#     {'t': 1746936006, 'p': 0.9845},
#     {'t': 1746939606, 'p': 0.9845},
#     {'t': 1746943206, 'p': 0.984},
#     {'t': 1746946807, 'p': 0.984},
#     {'t': 1746950406, 'p': 0.984},
#     {'t': 1746954007, 'p': 0.9845},
#     {'t': 1746957607, 'p': 0.9845},
#     {'t': 1746961207, 'p': 0.9845},
#     {'t': 1746964807, 'p': 0.9845},
#     {'t': 1746968406, 'p': 0.984},
#     {'t': 1746972007, 'p': 0.9815},
#     {'t': 1746975606, 'p': 0.982},
#     {'t': 1746979207, 'p': 0.9815},
#     {'t': 1746982806, 'p': 0.982},
#     {'t': 1746986407, 'p': 0.9825},
#     {'t': 1746990007, 'p': 0.9825},
#     {'t': 1746993607, 'p': 0.9825},
#     {'t': 1746997206, 'p': 0.982},
#     {'t': 1747000806, 'p': 0.9815},
#     {'t': 1747004406, 'p': 0.979},
#     {'t': 1747008006, 'p': 0.9815},
#     {'t': 1747011606, 'p': 0.981},
#     {'t': 1747015206, 'p': 0.9825},
#     {'t': 1747018806, 'p': 0.9835},
#     {'t': 1747022406, 'p': 0.984},
#     {'t': 1747026006, 'p': 0.984},
#     {'t': 1747029607, 'p': 0.983},
#     {'t': 1747033206, 'p': 0.984},
#     {'t': 1747036806, 'p': 0.985},
#     {'t': 1747040406, 'p': 0.985},
#     {'t': 1747044006, 'p': 0.985},
#     {'t': 1747047607, 'p': 0.985},
#     {'t': 1747051206, 'p': 0.9845},
#     {'t': 1747054806, 'p': 0.984},
#     {'t': 1747058406, 'p': 0.984},
#     {'t': 1747062007, 'p': 0.985},
#     {'t': 1747065606, 'p': 0.985},
#     {'t': 1747069206, 'p': 0.985},
#     {'t': 1747072805, 'p': 0.985},
#     {'t': 1747076406, 'p': 0.985},
#     {'t': 1747080007, 'p': 0.985},
#     {'t': 1747083607, 'p': 0.991},
#     {'t': 1747087205, 'p': 0.99},
#     {'t': 1747090806, 'p': 0.99},
#     {'t': 1747094406, 'p': 0.992},
#     {'t': 1747098007, 'p': 0.9905},
#     {'t': 1747101606, 'p': 0.9925},
#     {'t': 1747105207, 'p': 0.99},
#     {'t': 1747108806, 'p': 0.9915},
#     {'t': 1747112407, 'p': 0.9915},
#     {'t': 1747116007, 'p': 0.9905},
#     {'t': 1747119607, 'p': 0.9945},
#     {'t': 1747123206, 'p': 0.9945},
#     {'t': 1747126807, 'p': 0.9945},
#     {'t': 1747130406, 'p': 0.9945},
#     {'t': 1747134007, 'p': 0.9945},
#     {'t': 1747137607, 'p': 0.9945},
#     {'t': 1747141207, 'p': 0.9945},
#     {'t': 1747144806, 'p': 0.9945},
#     {'t': 1747148406, 'p': 0.9945},
#     {'t': 1747152007, 'p': 0.992},
#     {'t': 1747155607, 'p': 0.994},
#     {'t': 1747159207, 'p': 0.9935},
#     {'t': 1747162806, 'p': 0.994},
#     {'t': 1747166407, 'p': 0.989},
#     {'t': 1747170007, 'p': 0.9925},
#     {'t': 1747173607, 'p': 0.9995},
#     {'t': 1747177207, 'p': 0.9995},
#     {'t': 1747180807, 'p': 0.9995},
#     {'t': 1747184407, 'p': 0.9995}]}]}

# %%
# for i, m in enumerate(event['markets']):
#     prognosis = eval(m['outcomes'])[predictions[i]]
#     print(f"Market {m['question']}, Prediction: {prognosis}")
    
#     predictions[i]

predictions[i]
# Out:
# tensor([1])
